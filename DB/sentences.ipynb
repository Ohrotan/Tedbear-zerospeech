# %%
import numpy as np
import pandas as pd
import mysql.connector

# %%
data = pd.read_csv('../ted_scrap/data/final.csv')
data = data.where(pd.notnull(data), None)

# %%
data.rename(columns = {"start": "start_time",

 "end": "end_time"}, inplace = True)

# %%
mydb = mysql.connector.connect(
    host = "localhost",
    user = "root",
    port = 3306,
    password = "1234",
    database = "tedbear",
     auth_plugin='mysql_native_password')

mycursor = mydb.cursor()

# %%
cols = "`,`".join([str(i) for i in data.columns.tolist()])

# Insert DataFrame recrds one by one.
for i,row in data.iterrows():
    sql = "INSERT INTO sentence (`" +cols + "`) VALUES (" + "%s,"*(len(row)-1) + "%s)"
    mycursor.execute(sql, tuple(row))

    # the connection is not autocommitted by default, so we must commit to save our changes
mydb.commit()
# Out:
# 0 sentence      We are at a remarkable moment in time.
# start_time                                     25.131
# end_time                                       29.156
# duration                                        4.025
# talks_id                                         2093
# Name: 0, dtype: object
# 1 sentence       We face over the next two decades  two fundam...
# start_time                                               29.156
# end_time                                                 41.385
# duration                                                 12.229
# talks_id                                                   2093
# Name: 1, dtype: object
# 2 sentence      Let me illustrate with an example.
# start_time                                 41.385
# end_time                                   44.107
# duration                                    2.722
# talks_id                                     2093
# Name: 2, dtype: object
# 3 sentence       I first visited Beijing 25 years ago to teach...
# start_time                                               44.107
# end_time                                                 50.407
# duration                                                    6.3
# talks_id                                                   2093
# Name: 3, dtype: object
# 4 sentence       China was getting serious about market econom...
# start_time                                               50.407
# end_time                                                 60.173
# duration                                                  9.766
# talks_id                                                   2093
# Name: 4, dtype: object
# 5 sentence       Like most other people, I moved around Beijin...
# start_time                                               60.173
# end_time                                                 64.594
# duration                                                  4.421
# talks_id                                                   2093
# Name: 5, dtype: object
# 6 sentence       Apart from dodging the occasional vehicle, it...
# start_time                                               64.594
# end_time                                                 70.095
# duration                                                  5.501
# talks_id                                                   2093
# Name: 6, dtype: object
# 7 sentence       Cycling in Beijing now is a completely differ...
# start_time                                               70.095
# end_time                                                  74.28
# duration                                                  4.185
# talks_id                                                   2093
# Name: 7, dtype: object
# 8 sentence      The roads are jammed by cars and trucks.
# start_time                                        74.28
# end_time                                         77.423
# duration                                          3.143
# talks_id                                           2093
# Name: 8, dtype: object
# 9 sentence       The air is dangerously polluted from the burn...
# start_time                                               77.423
# end_time                                                 82.834
# duration                                                  5.411
# talks_id                                                   2093
# Name: 9, dtype: object
# 10 sentence       When I was there last in the spring,  there w...
# start_time                                               82.834
# end_time                                                 93.049
# duration                                                 10.215
# talks_id                                                   2093
# Name: 10, dtype: object
# 11 sentence       How did this come about?  It came from the wa...
# start_time                                               93.049
# end_time                                                 99.668
# duration                                                  6.619
# talks_id                                                   2093
# Name: 11, dtype: object
# 12 sentence       It's doubled over those 25 years, more than d...
# start_time                                               99.668
# end_time                                                104.304
# duration                                                  4.636
# talks_id                                                   2093
# Name: 12, dtype: object
# 13 sentence       It's become a sprawling urban area  dependent...
# start_time                                              104.304
# end_time                                                112.179
# duration                                                  7.875
# talks_id                                                   2093
# Name: 13, dtype: object
# 14 sentence       China burns half the world's coal each year, ...
# start_time                                              112.179
# end_time                                                125.307
# duration                                                 13.128
# talks_id                                                   2093
# Name: 14, dtype: object
# 15 sentence       At the same time, we have to recognize that i...
# start_time                                              125.307
# end_time                                                130.605
# duration                                                  5.298
# talks_id                                                   2093
# Name: 15, dtype: object
# 16 sentence      It has become the world's second largest econo...
# start_time                                              130.605
# end_time                                                133.046
# duration                                                  2.441
# talks_id                                                   2093
# Name: 16, dtype: object
# 17 sentence       Hundreds of millions of people have been lift...
# start_time                                              133.046
# end_time                                                 136.68
# duration                                                  3.634
# talks_id                                                   2093
# Name: 17, dtype: object
# 18 sentence      That's really important.
# start_time                       136.68
# end_time                        138.761
# duration                          2.081
# talks_id                           2093
# Name: 18, dtype: object
# 19 sentence       But at the same time, the people of China  ar...
# start_time                                              138.761
# end_time                                                154.161
# duration                                                   15.4
# talks_id                                                   2093
# Name: 19, dtype: object
# 20 sentence      China's planning to scale back coal.
# start_time                                  154.161
# end_time                                     156.49
# duration                                      2.329
# talks_id                                       2093
# Name: 20, dtype: object
# 21 sentence      It's looking to build its cities in different ...
# start_time                                               156.49
# end_time                                                162.351
# duration                                                  5.861
# talks_id                                                   2093
# Name: 21, dtype: object
# 22 sentence       Now, the growth of China  is part of a dramat...
# start_time                                              162.351
# end_time                                                170.675
# duration                                                  8.324
# talks_id                                                   2093
# Name: 22, dtype: object
# 23 sentence       Just 25 years ago, the developing countries, ...
# start_time                                              170.675
# end_time                                                183.028
# duration                                                 12.353
# talks_id                                                   2093
# Name: 23, dtype: object
# 24 sentence       Now it's more than half;  25 years from now, ...
# start_time                                              183.028
# end_time                                                192.124
# duration                                                  9.096
# talks_id                                                   2093
# Name: 24, dtype: object
# 25 sentence      That's a remarkable change.
# start_time                         192.124
# end_time                           193.722
# duration                             1.598
# talks_id                              2093
# Name: 25, dtype: object
# 26 sentence       It means that most countries around the world...
# start_time                                              193.722
# end_time                                                203.348
# duration                                                  9.626
# talks_id                                                   2093
# Name: 26, dtype: object
# 27 sentence       Now, the first of these transformations  is t...
# start_time                                              203.348
# end_time                                                215.248
# duration                                                   11.9
# talks_id                                                   2093
# Name: 27, dtype: object
# 28 sentence      Fifty percent now in urban areas.
# start_time                               215.248
# end_time                                 218.207
# duration                                   2.959
# talks_id                                    2093
# Name: 28, dtype: object
# 29 sentence      That's going to go to 70 percent in 2050.
# start_time                                       218.207
# end_time                                         221.818
# duration                                           3.611
# talks_id                                            2093
# Name: 29, dtype: object
# 30 sentence       Over the next two decades, we'll see  the dem...
# start_time                                              221.818
# end_time                                                237.814
# duration                                                 15.996
# talks_id                                                   2093
# Name: 30, dtype: object
# 31 sentence      This is profound structural change.
# start_time                                 237.814
# end_time                                   241.099
# duration                                     3.285
# talks_id                                      2093
# Name: 31, dtype: object
# 32 sentence       If we manage it in a negligent  or a shortsig...
# start_time                                              241.099
# end_time                                                252.709
# duration                                                  11.61
# talks_id                                                   2093
# Name: 32, dtype: object
# 33 sentence       If we think of those three areas that I have ...
# start_time                                              252.709
# end_time                                                267.524
# duration                                                 14.815
# talks_id                                                   2093
# Name: 33, dtype: object
# 34 sentence       And more than that,  the emissions of greenho...
# start_time                                              267.524
# end_time                                                276.535
# duration                                                  9.011
# talks_id                                                   2093
# Name: 34, dtype: object
# 35 sentence       Concentrations of greenhouse gases  in the at...
# start_time                                              276.535
# end_time                                                285.134
# duration                                                  8.599
# talks_id                                                   2093
# Name: 35, dtype: object
# 36 sentence       If we go on increasing those concentrations, ...
# start_time                                              285.134
# end_time                                                296.968
# duration                                                 11.834
# talks_id                                                   2093
# Name: 36, dtype: object
# 37 sentence       We've been around as Homo sapiens —  that's a...
# start_time                                              296.968
# end_time                                                305.068
# duration                                                    8.1
# talks_id                                                   2093
# Name: 37, dtype: object
# 38 sentence       We risk temperatures we haven't seen for tens...
# start_time                                              305.068
# end_time                                                311.038
# duration                                                   5.97
# talks_id                                                   2093
# Name: 38, dtype: object
# 39 sentence       That would transform the relationship between...
# start_time                                              311.038
# end_time                                                317.337
# duration                                                  6.299
# talks_id                                                   2093
# Name: 39, dtype: object
# 40 sentence       It would lead to changing deserts,  changing ...
# start_time                                              317.337
# end_time                                                336.523
# duration                                                 19.186
# talks_id                                                   2093
# Name: 40, dtype: object
# 41 sentence      And we couldn't just turn it off.
# start_time                               336.523
# end_time                                 338.401
# duration                                   1.878
# talks_id                                    2093
# Name: 41, dtype: object
# 42 sentence      You can't make a peace treaty with the planet.
# start_time                                            338.401
# end_time                                              340.831
# duration                                                 2.43
# talks_id                                                 2093
# Name: 42, dtype: object
# 43 sentence      You can't negotiate with the laws of physics.
# start_time                                           340.831
# end_time                                             343.058
# duration                                               2.227
# talks_id                                                2093
# Name: 43, dtype: object
# 44 sentence      You're in there. You're stuck.
# start_time                            343.058
# end_time                              344.773
# duration                                1.715
# talks_id                                 2093
# Name: 44, dtype: object
# 45 sentence       Those are the stakes we're playing for,  and ...
# start_time                                              344.773
# end_time                                                353.194
# duration                                                  8.421
# talks_id                                                   2093
# Name: 45, dtype: object
# 46 sentence       Now, the first of these transformations is go...
# start_time                                              353.194
# end_time                                                356.653
# duration                                                  3.459
# talks_id                                                   2093
# Name: 46, dtype: object
# 47 sentence       We have to decide whether to do it well or ba...
# start_time                                              356.653
# end_time                                                 361.32
# duration                                                  4.667
# talks_id                                                   2093
# Name: 47, dtype: object
# 48 sentence       But the second of the transformations, the cl...
# start_time                                               361.32
# end_time                                                367.324
# duration                                                  6.004
# talks_id                                                   2093
# Name: 48, dtype: object
# 49 sentence       Those two transformations face us in the next...
# start_time                                              367.324
# end_time                                                371.716
# duration                                                  4.392
# talks_id                                                   2093
# Name: 49, dtype: object
# 50 sentence       The next two decades are decisive for what we...
# start_time                                              371.716
# end_time                                                377.644
# duration                                                  5.928
# talks_id                                                   2093
# Name: 50, dtype: object
# 51 sentence       Now, the more I've thought about this,  the t...
# start_time                                              377.644
# end_time                                                385.766
# duration                                                  8.122
# talks_id                                                   2093
# Name: 51, dtype: object
# 52 sentence       It's an opportunity which we can use or it's ...
# start_time                                              385.766
# end_time                                                 391.39
# duration                                                  5.624
# talks_id                                                   2093
# Name: 52, dtype: object
# 53 sentence       And let me explain through those three key ar...
# start_time                                               391.39
# end_time                                                396.823
# duration                                                  5.433
# talks_id                                                   2093
# Name: 53, dtype: object
# 54 sentence      And let me start with cities.
# start_time                           396.823
# end_time                             398.877
# duration                               2.054
# talks_id                                2093
# Name: 54, dtype: object
# 55 sentence       I've already described the problems of Beijin...
# start_time                                              398.877
# end_time                                                405.756
# duration                                                  6.879
# talks_id                                                   2093
# Name: 55, dtype: object
# 56 sentence       Surely we recognize that in many of our citie...
# start_time                                              405.756
# end_time                                                410.705
# duration                                                  4.949
# talks_id                                                   2093
# Name: 56, dtype: object
# 57 sentence       Now, with cities, like life but particularly ...
# start_time                                              410.705
# end_time                                                416.694
# duration                                                  5.989
# talks_id                                                   2093
# Name: 57, dtype: object
# 58 sentence       The cities that are going to be built —  and ...
# start_time                                              416.694
# end_time                                                426.522
# duration                                                  9.828
# talks_id                                                   2093
# Name: 58, dtype: object
# 59 sentence       The cities that already are  there, well esta...
# start_time                                              426.522
# end_time                                                442.269
# duration                                                 15.747
# talks_id                                                   2093
# Name: 59, dtype: object
# 60 sentence       We've got examples building around the world ...
# start_time                                              442.269
# end_time                                                446.971
# duration                                                  4.702
# talks_id                                                   2093
# Name: 60, dtype: object
# 61 sentence       The bus rapid transport system in Bogotá in C...
# start_time                                              446.971
# end_time                                                472.564
# duration                                                 25.593
# talks_id                                                   2093
# Name: 61, dtype: object
# 62 sentence      Now, some things in cities do take time.
# start_time                                      472.564
# end_time                                        474.465
# duration                                          1.901
# talks_id                                           2093
# Name: 62, dtype: object
# 63 sentence      Some things in cities can happen much more qui...
# start_time                                              474.465
# end_time                                                477.518
# duration                                                  3.053
# talks_id                                                   2093
# Name: 63, dtype: object
# 64 sentence      Take my hometown, London.
# start_time                       477.518
# end_time                         479.622
# duration                           2.104
# talks_id                            2093
# Name: 64, dtype: object
# 65 sentence       In 1952, smog in London killed 4,000 people a...
# start_time                                              479.622
# end_time                                                487.604
# duration                                                  7.982
# talks_id                                                   2093
# Name: 65, dtype: object
# 66 sentence      And it happened all the time.
# start_time                           487.604
# end_time                             488.954
# duration                                1.35
# talks_id                                2093
# Name: 66, dtype: object
# 67 sentence      For those of you live outside London in the U.K.
# start_time                                              488.954
# end_time                                                491.456
# duration                                                  2.502
# talks_id                                                   2093
# Name: 67, dtype: object
# 68 sentence      will remember it used to be called The Smoke.
# start_time                                           491.456
# end_time                                             493.649
# duration                                               2.193
# talks_id                                                2093
# Name: 68, dtype: object
# 69 sentence      That's the way London was.
# start_time                        493.649
# end_time                          495.325
# duration                            1.676
# talks_id                             2093
# Name: 69, dtype: object
# 70 sentence       By regulating coal, within a few years the pr...
# start_time                                              495.325
# end_time                                                500.495
# duration                                                   5.17
# talks_id                                                   2093
# Name: 70, dtype: object
# 71 sentence      I remember the smogs well.
# start_time                        500.495
# end_time                           502.05
# duration                            1.555
# talks_id                             2093
# Name: 71, dtype: object
# 72 sentence       When the visibility dropped to [less] than  a...
# start_time                                               502.05
# end_time                                                508.622
# duration                                                  6.572
# talks_id                                                   2093
# Name: 72, dtype: object
# 73 sentence      This was the 1950s.
# start_time                 508.622
# end_time                    510.68
# duration                     2.058
# talks_id                      2093
# Name: 73, dtype: object
# 74 sentence      I had to walk home three miles from school.
# start_time                                          510.68
# end_time                                           514.578
# duration                                             3.898
# talks_id                                              2093
# Name: 74, dtype: object
# 75 sentence      Again, breathing was a hazardous activity.
# start_time                                        514.578
# end_time                                          518.147
# duration                                            3.569
# talks_id                                             2093
# Name: 75, dtype: object
# 76 sentence      But it was changed. It was changed by a decisi...
# start_time                                              518.147
# end_time                                                520.825
# duration                                                  2.678
# talks_id                                                   2093
# Name: 76, dtype: object
# 77 sentence       Good decisions can bring good results, striki...
# start_time                                              520.825
# end_time                                                526.359
# duration                                                  5.534
# talks_id                                                   2093
# Name: 77, dtype: object
# 78 sentence       We've seen more: In London, we've introduced ...
# start_time                                              526.359
# end_time                                                 537.64
# duration                                                 11.281
# talks_id                                                   2093
# Name: 78, dtype: object
# 79 sentence       You can see that the two transformations I've...
# start_time                                               537.64
# end_time                                                545.348
# duration                                                  7.708
# talks_id                                                   2093
# Name: 79, dtype: object
# 80 sentence      But we have to invest. We have to invest in ou...
# start_time                                              545.348
# end_time                                                548.281
# duration                                                  2.933
# talks_id                                                   2093
# Name: 80, dtype: object
# 81 sentence       and we have to invest wisely, and if we do,  ...
# start_time                                              548.281
# end_time                                                567.071
# duration                                                  18.79
# talks_id                                                   2093
# Name: 81, dtype: object
# 82 sentence       We can do that, but we have to think, we have...
# start_time                                              567.071
# end_time                                                571.208
# duration                                                  4.137
# talks_id                                                   2093
# Name: 82, dtype: object
# 83 sentence      Let me turn to energy.
# start_time                    571.208
# end_time                      573.379
# duration                        2.171
# talks_id                         2093
# Name: 83, dtype: object
# 84 sentence       Now, energy over the last 25 years has increa...
# start_time                                              573.379
# end_time                                                578.837
# duration                                                  5.458
# talks_id                                                   2093
# Name: 84, dtype: object
# 85 sentence      Eighty percent of that comes from fossil fuels.
# start_time                                             578.837
# end_time                                               581.454
# duration                                                 2.617
# talks_id                                                  2093
# Name: 85, dtype: object
# 86 sentence       Over the next 20 years, perhaps it will incre...
# start_time                                              581.454
# end_time                                                586.888
# duration                                                  5.434
# talks_id                                                   2093
# Name: 86, dtype: object
# 87 sentence       We have to invest strongly in energy,  we hav...
# start_time                                              586.888
# end_time                                                594.384
# duration                                                  7.496
# talks_id                                                   2093
# Name: 87, dtype: object
# 88 sentence      We can see how to do that.
# start_time                        594.384
# end_time                          595.714
# duration                             1.33
# talks_id                             2093
# Name: 88, dtype: object
# 89 sentence      Take the example of California.
# start_time                             595.714
# end_time                               597.618
# duration                                 1.904
# talks_id                                  2093
# Name: 89, dtype: object
# 90 sentence       It would be in the top 10 countries in the wo...
# start_time                                              597.618
# end_time                                                602.771
# duration                                                  5.153
# talks_id                                                   2093
# Name: 90, dtype: object
# 91 sentence       I don't want to start any —  (Laughter) Calif...
# start_time                                              602.771
# end_time                                                610.679
# duration                                                  7.908
# talks_id                                                   2093
# Name: 91, dtype: object
# 92 sentence       (Laughter)  In the next five or six years,  t...
# start_time                                              610.679
# end_time                                                634.756
# duration                                                 24.077
# talks_id                                                   2093
# Name: 92, dtype: object
# 93 sentence      That's a striking achievement.
# start_time                            634.756
# end_time                              636.206
# duration                                 1.45
# talks_id                                 2093
# Name: 93, dtype: object
# 94 sentence      It shows what can be done.
# start_time                        636.206
# end_time                          637.689
# duration                            1.483
# talks_id                             2093
# Name: 94, dtype: object
# 95 sentence       Not just California — the  incoming governmen...
# start_time                                              637.689
# end_time                                                649.169
# duration                                                  11.48
# talks_id                                                   2093
# Name: 95, dtype: object
# 96 sentence      They've set themselves a target of five years.
# start_time                                            649.169
# end_time                                              651.649
# duration                                                 2.48
# talks_id                                                 2093
# Name: 96, dtype: object
# 97 sentence      I think they've got a good chance of doing that.
# start_time                                              651.649
# end_time                                                654.878
# duration                                                  3.229
# talks_id                                                   2093
# Name: 97, dtype: object
# 98 sentence       We'll see, but what you're seeing now is peop...
# start_time                                              654.878
# end_time                                                659.848
# duration                                                   4.97
# talks_id                                                   2093
# Name: 98, dtype: object
# 99 sentence       Four hundred million, more than the populatio...
# start_time                                              659.848
# end_time                                                663.708
# duration                                                   3.86
# talks_id                                                   2093
# Name: 99, dtype: object
# 100 sentence       Those are the kinds of ambitions now  people ...
# start_time                                              663.708
# end_time                                                671.987
# duration                                                  8.279
# talks_id                                                   2093
# Name: 100, dtype: object
# 101 sentence       Again, you can see  good decisions can bring ...
# start_time                                              671.987
# end_time                                                683.305
# duration                                                 11.318
# talks_id                                                   2093
# Name: 101, dtype: object
# 102 sentence       Do the first one well, the structural,  the s...
# start_time                                              683.305
# end_time                                                 690.29
# duration                                                  6.985
# talks_id                                                   2093
# Name: 102, dtype: object
# 103 sentence       Look at land, land and particularly forests.
# start_time                                            690.29
# end_time                                             694.667
# duration                                               4.377
# talks_id                                                2093
# Name: 103, dtype: object
# 104 sentence       Forests are the hosts to valuable plant and a...
# start_time                                              694.667
# end_time                                                700.256
# duration                                                  5.589
# talks_id                                                   2093
# Name: 104, dtype: object
# 105 sentence       They hold water in the soil  and they take ca...
# start_time                                              700.256
# end_time                                                708.591
# duration                                                  8.335
# talks_id                                                   2093
# Name: 105, dtype: object
# 106 sentence      But we're losing our forests.
# start_time                           708.591
# end_time                             710.823
# duration                               2.232
# talks_id                                2093
# Name: 106, dtype: object
# 107 sentence       In the last decade, we've lost a forest area ...
# start_time                                              710.823
# end_time                                                718.256
# duration                                                  7.433
# talks_id                                                   2093
# Name: 107, dtype: object
# 108 sentence       But we're already seeing that we can do so mu...
# start_time                                              718.256
# end_time                                                722.418
# duration                                                  4.162
# talks_id                                                   2093
# Name: 108, dtype: object
# 109 sentence       We can recognize the problem, but we can also...
# start_time                                              722.418
# end_time                                                726.569
# duration                                                  4.151
# talks_id                                                   2093
# Name: 109, dtype: object
# 110 sentence       In Brazil, the rate of deforestation  has bee...
# start_time                                              726.569
# end_time                                                733.803
# duration                                                  7.234
# talks_id                                                   2093
# Name: 110, dtype: object
# 111 sentence       How? By involving local communities,  investi...
# start_time                                              733.803
# end_time                                                745.354
# duration                                                 11.551
# talks_id                                                   2093
# Name: 111, dtype: object
# 112 sentence      And it's not just stopping deforestation.
# start_time                                       745.354
# end_time                                         747.244
# duration                                            1.89
# talks_id                                            2093
# Name: 112, dtype: object
# 113 sentence       That's of course of first and fundamental imp...
# start_time                                              747.244
# end_time                                                757.707
# duration                                                 10.463
# talks_id                                                   2093
# Name: 113, dtype: object
# 114 sentence      I first went to Ethiopia in 1967.
# start_time                               757.707
# end_time                                 761.587
# duration                                    3.88
# talks_id                                    2093
# Name: 114, dtype: object
# 115 sentence      It was desperately poor. In the following years,
# start_time                                              761.587
# end_time                                                764.062
# duration                                                  2.475
# talks_id                                                   2093
# Name: 115, dtype: object
# 116 sentence       it suffered devastating famines and profoundl...
# start_time                                              764.062
# end_time                                                769.664
# duration                                                  5.602
# talks_id                                                   2093
# Name: 116, dtype: object
# 117 sentence       Over the last few years, actually more than a...
# start_time                                              769.664
# end_time                                                775.423
# duration                                                  5.759
# talks_id                                                   2093
# Name: 117, dtype: object
# 118 sentence       It has ambitions to be a middle-income countr...
# start_time                                              775.423
# end_time                                                782.061
# duration                                                  6.638
# talks_id                                                   2093
# Name: 118, dtype: object
# 119 sentence       Again, I think it's a strong ambition but it ...
# start_time                                              782.061
# end_time                                                787.404
# duration                                                  5.343
# talks_id                                                   2093
# Name: 119, dtype: object
# 120 sentence      You're seeing that commitment there.
# start_time                                  787.404
# end_time                                    788.815
# duration                                      1.411
# talks_id                                       2093
# Name: 120, dtype: object
# 121 sentence      You're seeing what can be done.
# start_time                             788.815
# end_time                               790.081
# duration                                 1.266
# talks_id                                  2093
# Name: 121, dtype: object
# 122 sentence      Ethiopia is investing in clean energy.
# start_time                                    790.081
# end_time                                      792.646
# duration                                        2.565
# talks_id                                         2093
# Name: 122, dtype: object
# 123 sentence      It's working in the rehabilitation of land.
# start_time                                         792.646
# end_time                                           796.268
# duration                                             3.622
# talks_id                                              2093
# Name: 123, dtype: object
# 124 sentence       In Humbo, in southwest Ethiopia,  a wonderful...
# start_time                                              796.268
# end_time                                                809.408
# duration                                                  13.14
# talks_id                                                   2093
# Name: 124, dtype: object
# 125 sentence       So we can see, from Beijing to London,  from ...
# start_time                                              809.408
# end_time                                                824.431
# duration                                                 15.023
# talks_id                                                   2093
# Name: 125, dtype: object
# 126 sentence      We do understand how to manage those well.
# start_time                                        824.431
# end_time                                           828.61
# duration                                            4.179
# talks_id                                             2093
# Name: 126, dtype: object
# 127 sentence      And technology is changing very rapidly.
# start_time                                       828.61
# end_time                                        831.388
# duration                                          2.778
# talks_id                                           2093
# Name: 127, dtype: object
# 128 sentence       I don't have to list all those things  to an ...
# start_time                                              831.388
# end_time                                                841.064
# duration                                                  9.676
# talks_id                                                   2093
# Name: 128, dtype: object
# 129 sentence       You can see that we can manage remotely now o...
# start_time                                              841.064
# end_time                                                847.014
# duration                                                   5.95
# talks_id                                                   2093
# Name: 129, dtype: object
# 130 sentence      You can see better insulation.
# start_time                            847.014
# end_time                              848.821
# duration                                1.807
# talks_id                                 2093
# Name: 130, dtype: object
# 131 sentence      And there's much more coming.
# start_time                           848.821
# end_time                             850.744
# duration                               1.923
# talks_id                                2093
# Name: 131, dtype: object
# 132 sentence       But, and it's a big but,  the world as a whol...
# start_time                                              850.744
# end_time                                                857.528
# duration                                                  6.784
# talks_id                                                   2093
# Name: 132, dtype: object
# 133 sentence      We're not cutting emissions in the way we shou...
# start_time                                              857.528
# end_time                                                 860.07
# duration                                                  2.542
# talks_id                                                   2093
# Name: 133, dtype: object
# 134 sentence       We're not managing those structural transform...
# start_time                                               860.07
# end_time                                                 865.01
# duration                                                   4.94
# talks_id                                                   2093
# Name: 134, dtype: object
# 135 sentence       The depth of understanding of the immense ris...
# start_time                                               865.01
# end_time                                                871.828
# duration                                                  6.818
# talks_id                                                   2093
# Name: 135, dtype: object
# 136 sentence       The depth of understanding  of the attractive...
# start_time                                              871.828
# end_time                                                880.108
# duration                                                   8.28
# talks_id                                                   2093
# Name: 136, dtype: object
# 137 sentence      We need political pressure to build.
# start_time                                  880.108
# end_time                                    883.606
# duration                                      3.498
# talks_id                                       2093
# Name: 137, dtype: object
# 138 sentence      We need leaders to step up.
# start_time                         883.606
# end_time                           887.138
# duration                             3.532
# talks_id                              2093
# Name: 138, dtype: object
# 139 sentence       We can have better growth, better climate, a ...
# start_time                                              887.138
# end_time                                                894.844
# duration                                                  7.706
# talks_id                                                   2093
# Name: 139, dtype: object
# 140 sentence       We can make,  by managing those two transform...
# start_time                                              894.844
# end_time                                                903.724
# duration                                                   8.88
# talks_id                                                   2093
# Name: 140, dtype: object
# 141 sentence       If we make a mess of it,  we, you and me, if ...
# start_time                                              903.724
# end_time                                                916.193
# duration                                                 12.469
# talks_id                                                   2093
# Name: 141, dtype: object
# 142 sentence       That's the major conclusion  of the report on...
# start_time                                              916.193
# end_time                                                 933.68
# duration                                                 17.487
# talks_id                                                   2093
# Name: 142, dtype: object
# 143 sentence      Ban Ki-moon.
# start_time           933.68
# end_time            934.946
# duration              1.266
# talks_id               2093
# Name: 143, dtype: object
# 144 sentence      We know that we can do this.
# start_time                          934.946
# end_time                            939.051
# duration                              4.105
# talks_id                               2093
# Name: 144, dtype: object
# 145 sentence       Now, two weeks ago, I became a grandfather fo...
# start_time                                              939.051
# end_time                                                945.833
# duration                                                  6.782
# talks_id                                                   2093
# Name: 145, dtype: object
# 146 sentence       Our daughter —  (Baby cries) (Laughter) (Appl...
# start_time                                              945.833
# end_time                                                964.484
# duration                                                 18.651
# talks_id                                                   2093
# Name: 146, dtype: object
# 147 sentence       (Applause) Two weeks old.
# start_time                        964.484
# end_time                          974.696
# duration                           10.212
# ...
# Name: 2294, dtype: object
# 2295 sentence       After one harvest, they had increased their i...
# start_time                                              497.858
# end_time                                                504.858
# duration                                                      7
# talks_id                                                     91
# Name: 2295, dtype: object
# 2296 sentence      A couple of years later, I meet them.
# start_time                                   504.858
# end_time                                     506.858
# duration                                           2
# talks_id                                          91
# Name: 2296, dtype: object
# 2297 sentence       They now make four dollars a day, which is pr...
# start_time                                              506.858
# end_time                                                515.858
# duration                                                      9
# talks_id                                                     91
# Name: 2297, dtype: object
# 2298 sentence      And I swear, you could see the future in that ...
# start_time                                              515.858
# end_time                                                518.858
# duration                                                      3
# talks_id                                                     91
# Name: 2298, dtype: object
# 2299 sentence      Something I truly believe.
# start_time                        518.858
# end_time                          520.858
# duration                                2
# talks_id                               91
# Name: 2299, dtype: object
# 2300 sentence       You can't talk about poverty today without ta...
# start_time                                              520.858
# end_time                                                533.858
# duration                                                     13
# talks_id                                                     91
# Name: 2300, dtype: object
# 2301 sentence      Malaria is a disease that kills one to three m...
# start_time                                              533.858
# end_time                                                537.858
# duration                                                      4
# talks_id                                                     91
# Name: 2301, dtype: object
# 2302 sentence      300 to 500 million cases are reported.
# start_time                                    537.858
# end_time                                      539.858
# duration                                            2
# talks_id                                           91
# Name: 2302, dtype: object
# 2303 sentence       It's estimated that Africa loses about 13 bil...
# start_time                                              539.858
# end_time                                                543.858
# duration                                                      4
# talks_id                                                     91
# Name: 2303, dtype: object
# 2304 sentence      Five dollars can save a life.
# start_time                           543.858
# end_time                             545.858
# duration                                   2
# talks_id                                  91
# Name: 2304, dtype: object
# 2305 sentence       We can send people to the moon; we can see if...
# start_time                                              545.858
# end_time                                                561.858
# duration                                                     16
# talks_id                                                     91
# Name: 2305, dtype: object
# 2306 sentence      One: production is too low. Two: price is too ...
# start_time                                              561.858
# end_time                                                564.858
# duration                                                      3
# talks_id                                                     91
# Name: 2306, dtype: object
# 2307 sentence      Three: this is a good road in -- right near wh...
# start_time                                              564.858
# end_time                                                569.858
# duration                                                      5
# talks_id                                                     91
# Name: 2307, dtype: object
# 2308 sentence      Distribution is a nightmare, but not impossible.
# start_time                                              569.858
# end_time                                                572.858
# duration                                                      3
# talks_id                                                     91
# Name: 2308, dtype: object
# 2309 sentence       We started by making a 350,000-dollar loan  t...
# start_time                                              572.858
# end_time                                                585.858
# duration                                                     13
# talks_id                                                     91
# Name: 2309, dtype: object
# 2310 sentence      Here are just some pictures of the factory.
# start_time                                         585.858
# end_time                                           587.858
# duration                                                 2
# talks_id                                                91
# Name: 2310, dtype: object
# 2311 sentence       Today, three years later, the company has emp...
# start_time                                              587.858
# end_time                                                592.858
# duration                                                      5
# talks_id                                                     91
# Name: 2311, dtype: object
# 2312 sentence      It contributes about 600,000 dollars in wages ...
# start_time                                              593.858
# end_time                                                598.858
# duration                                                      5
# talks_id                                                     91
# Name: 2312, dtype: object
# 2313 sentence      It's the largest company in Tanzania.
# start_time                                   598.858
# end_time                                     600.858
# duration                                           2
# talks_id                                          91
# Name: 2313, dtype: object
# 2314 sentence      The throughput rate right now is 1.5 million n...
# start_time                                              600.858
# end_time                                                603.858
# duration                                                      3
# talks_id                                                     91
# Name: 2314, dtype: object
# 2315 sentence      three million by the end of the year.
# start_time                                   603.858
# end_time                                     605.858
# duration                                           2
# talks_id                                          91
# Name: 2315, dtype: object
# 2316 sentence      We hope to have seven million at the end of ne...
# start_time                                              605.858
# end_time                                                607.858
# duration                                                      2
# talks_id                                                     91
# Name: 2316, dtype: object
# 2317 sentence      So the production side is working.
# start_time                                608.858
# end_time                                  610.858
# duration                                        2
# talks_id                                       91
# Name: 2317, dtype: object
# 2318 sentence       On the distribution side, though, as a world,...
# start_time                                              610.858
# end_time                                                613.858
# duration                                                      3
# talks_id                                                     91
# Name: 2318, dtype: object
# 2319 sentence      Right now, 95 percent of these nets are being ...
# start_time                                              613.858
# end_time                                                617.858
# duration                                                      4
# talks_id                                                     91
# Name: 2319, dtype: object
# 2320 sentence      and then given primarily to people around Afri...
# start_time                                              617.858
# end_time                                                621.858
# duration                                                      4
# talks_id                                                     91
# Name: 2320, dtype: object
# 2321 sentence       We're looking at building on some of the most...
# start_time                                              621.858
# end_time                                                626.858
# duration                                                      5
# talks_id                                                     91
# Name: 2321, dtype: object
# 2322 sentence      Their women.
# start_time          626.858
# end_time            628.858
# duration                  2
# talks_id                 91
# Name: 2322, dtype: object
# 2323 sentence       And so I want you to meet Jacqueline, my name...
# start_time                                              628.858
# end_time                                                632.858
# duration                                                      4
# talks_id                                                     91
# Name: 2323, dtype: object
# 2324 sentence       If she were born anywhere else but Tanzania, ...
# start_time                                              632.858
# end_time                                                636.858
# duration                                                      4
# talks_id                                                     91
# Name: 2324, dtype: object
# 2325 sentence       She runs two of the lines, and has already sa...
# start_time                                              636.858
# end_time                                                642.858
# duration                                                      6
# talks_id                                                     91
# Name: 2325, dtype: object
# 2326 sentence       She makes about two dollars a day, is creatin...
# start_time                                              642.858
# end_time                                                652.858
# duration                                                     10
# talks_id                                                     91
# Name: 2326, dtype: object
# 2327 sentence       And so, when I told her about our idea --  th...
# start_time                                              652.858
# end_time                                                667.858
# duration                                                     15
# talks_id                                                     91
# Name: 2327, dtype: object
# 2328 sentence       We took a lesson from IDEO, one of our favori...
# start_time                                              667.858
# end_time                                                677.858
# duration                                                     10
# talks_id                                                     91
# Name: 2328, dtype: object
# 2329 sentence       She brought 10 of the women with whom she int...
# start_time                                              677.858
# end_time                                                689.858
# duration                                                     12
# talks_id                                                     91
# Name: 2329, dtype: object
# 2330 sentence       Not coming in with our own notions, because s...
# start_time                                              689.858
# end_time                                                693.858
# duration                                                      4
# talks_id                                                     91
# Name: 2330, dtype: object
# 2331 sentence      First, she talked about comfort, status, beauty.
# start_time                                              693.858
# end_time                                                696.858
# duration                                                      3
# talks_id                                                     91
# Name: 2331, dtype: object
# 2332 sentence      These nets, she said, you put them on the floo...
# start_time                                              696.858
# end_time                                                699.858
# duration                                                      3
# talks_id                                                     91
# Name: 2332, dtype: object
# 2333 sentence       Children can sleep through the night; the hou...
# start_time                                              699.858
# end_time                                                703.858
# duration                                                      4
# talks_id                                                     91
# Name: 2333, dtype: object
# 2334 sentence       And we've started making curtains,  and not o...
# start_time                                              703.858
# end_time                                                710.858
# duration                                                      7
# talks_id                                                     91
# Name: 2334, dtype: object
# 2335 sentence      Only then did she talk about saving your child...
# start_time                                              710.858
# end_time                                                714.858
# duration                                                      4
# talks_id                                                     91
# Name: 2335, dtype: object
# 2336 sentence       A lot of lessons to be learned in terms of ho...
# start_time                                              715.858
# end_time                                                721.858
# duration                                                      6
# talks_id                                                     91
# Name: 2336, dtype: object
# 2337 sentence       I want to end just by saying that there's eno...
# start_time                                              722.858
# end_time                                                729.858
# duration                                                      7
# talks_id                                                     91
# Name: 2337, dtype: object
# 2338 sentence       To do it right, we have to build business mod...
# start_time                                              729.858
# end_time                                                741.858
# duration                                                     12
# talks_id                                                     91
# Name: 2338, dtype: object
# 2339 sentence      Because at the end of the day, it's about enga...
# start_time                                              741.858
# end_time                                                744.858
# duration                                                      3
# talks_id                                                     91
# Name: 2339, dtype: object
# 2340 sentence       It's about understanding that people really d...
# start_time                                              744.858
# end_time                                                758.858
# duration                                                     14
# talks_id                                                     91
# Name: 2340, dtype: object
# 2341 sentence       And so I urge all of you to think next time  ...
# start_time                                              758.858
# end_time                                                777.858
# duration                                                     19
# talks_id                                                     91
# Name: 2341, dtype: object
# 2342 sentence      Thank you.
# start_time        777.858
# end_time          778.858
# duration                1
# talks_id               91
# Name: 2342, dtype: object

# %%
mycursor.close()
mydb.close()
