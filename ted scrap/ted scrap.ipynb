# %%
import requests
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
import pandas as pd

# %%
from TEDscraper import TEDscraper

# %%
cd C:/Users/youk2/TEDscraper-master
# Out:
# C:\Users\youk2\TEDscraper-master

# %%
# move to TEDscraper directory
# import module (or use Jupyter Notebook)

# instantiate the scraper & pass in optional arguments
scraper = TEDscraper(lang_code='en', urls='all', topics='all')

# scrape the data and save it to a dictionary
ted_dict = scraper.get_data()

# transform the dictionary to a sorted pandas DataFrame
df = scraper.to_dataframe(ted_dict)

# output DataFrame as CSV
df.to_csv('../data/ted_talks.csv', index=False)
# Out:
# Fetching urls...

# %%
scraper = TEDscraper(topics=['Sun'])
ted_dict = scraper.get_data()
df = scraper.to_dataframe(ted_dict)
df.to_csv('../data/ted_talks.csv', index=False)
# Out:
# Fetching urls...
#
# Scraping 6 TED talks in 'English'...
# Estimated time to complete is 0.1 minutes
#
# [OK] 0 https://www.ted.com/talks/kay_almere_read_the_aztec_myth_of_the_unlikeliest_sun_god/transcript?language=en
# [OK] 1 https://www.ted.com/talks/miho_janvier_lessons_from_a_solar_storm_chaser/transcript?language=en
# [OK] 2 https://www.ted.com/talks/david_baron_you_owe_it_to_yourself_to_experience_a_total_solar_eclipse/transcript?language=en
# [OK] 3 https://www.ted.com/talks/ron_shaneyfelt_is_space_trying_to_kill_us/transcript?language=en
# [OK] 4 https://www.ted.com/talks/lucianne_walkowicz_finding_planets_around_other_stars/transcript?language=en
# [OK] 5 https://www.ted.com/talks/garik_israelian_how_spectroscopy_could_reveal_alien_life/transcript?language=en
#
# Ted.com scraping results:
#
# 	• Successful: 6
#
# 	• Failed: 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-5a37cf138a78> in <module>
#       2 ted_dict = scraper.get_data()
#       3 df = scraper.to_dataframe(ted_dict)
# ----> 4 t.s = df.to_csv('../data/ted_talks.csv', index=False)
#
# NameError: name 't' is not defined

# %%
df
# Out:
#   talk_id                                              title  \
# 0     648           How spectroscopy could reveal alien life
# 1    1210                 Finding planets around other stars
# 2    2849  You owe it to yourself to experience a total s...
# 3    5116                  Lessons from a solar storm chaser
# 4   23894                        Is space trying to kill us?
# 5   40769          The Aztec myth of the unlikeliest sun god
#
#             speaker_1               all_speakers                  occupations  \
# 0     Garik Israelian     {0: 'Garik Israelian'}      {0: ['astrophysicist']}
# 1  Lucianne Walkowicz  {0: 'Lucianne Walkowicz'}  {0: ['stellar astronomer']}
# 2         David Baron         {0: 'David Baron'}      {0: ['science writer']}
# 3        Miho Janvier        {0: 'Miho Janvier'}     {0: ['space physicist']}
# 4      Ron Shaneyfelt      {0: 'Ron Shaneyfelt'}                         None
# 5          Kay A Read          {0: 'Kay A Read'}                         None
#
#                                       about_speakers    views recorded_date  \
# 0  {0: 'Garik Israelian's stargazing on the Canar...   663594    2009-07-23
# 1  {0: 'Lucianne Walkowicz works on NASA's Kepler...  1258115    2011-07-11
# 2  {0: 'David Baron writes about science in books...  2098847    2017-07-08
# 3  {0: 'TED Fellow Miho Janvier studies the the S...  1195536    2017-08-27
# 4                                               None   305659    2013-05-28
# 5                                               None  1117915    2019-05-09
#
#   published_date           event native_lang  \
# 0     2009-10-01  TEDGlobal 2009          en
# 1     2011-08-11  TEDGlobal 2011          en
# 2     2017-08-10    TEDxMileHigh          en
# 3     2017-12-12  TEDGlobal 2017          en
# 4     2019-04-01          TED-Ed          en
# 5     2019-05-09          TED-Ed          en
#
#                                       available_lang comments duration  \
# 0  [ar, bg, de, en, es, fr, he, hr, hu, hy, it, j...       71      952
# 1  [ar, az, bg, ca, cs, de, el, en, eo, es, fa, f...      140      264
# 2  [ar, en, es, fa, fr, he, hi, it, ja, ko, pl, p...       64      736
# 3  [ar, de, el, en, es, fa, fr, he, hi, hr, hu, i...        5      334
# 4  [ar, bg, en, es, fa, fr, he, it, ja, ko, ku, n...     None      196
# 5  [ar, bg, en, es, fa, fr, he, id, it, ja, ko, k...     None      238
#
#                                               topics  \
# 0  [astronomy, chemistry, life, science, technolo...
# 1  [TED Fellows, exploration, science, technology...
# 2  [beauty, astronomy, nature, science, solar sys...
# 3  [physics, space, TED Fellows, science, Sun, na...
# 4  [TED-Ed, space, animation, universe, Planets, ...
# 5  [TED-Ed, animals, Sun, animation, Moon, ancien...
#
#                                        related_talks  \
# 0  {306: 'Let's look for life in the outer solar ...
# 1  {920: 'How we found hundreds of potential Eart...
# 2  {2491: 'Adventures of an asteroid hunter', 272...
# 3  {2491: 'Adventures of an asteroid hunter', 284...
# 4  {23423: 'Could the Earth be swallowed by a bla...
# 5  {24436: 'The myth behind the Chinese zodiac', ...
#
#                                                  url  \
# 0  https://www.ted.com/talks/garik_israelian_how_...
# 1  https://www.ted.com/talks/lucianne_walkowicz_f...
# 2  https://www.ted.com/talks/david_baron_you_owe_...
# 3  https://www.ted.com/talks/miho_janvier_lessons...
# 4  https://www.ted.com/talks/ron_shaneyfelt_is_sp...
# 5  https://www.ted.com/talks/kay_almere_read_the_...
#
#                                          description  \
# 0  Garik Israelian is a spectroscopist, studying ...
# 1  How do we find planets -- even habitable plane...
# 2  On August 21, 2017, the moon's shadow raced fr...
# 3  Space physicist Miho Janvier studies solar sto...
# 4  How likely is it that a massive asteroid will ...
# 5  Nanahuatl, weakest of the Aztec gods, sickly a...
#
#                                           transcript
# 0  I have a very difficult task. I'm a spectrosco...
# 1  Planetary systems outside our own are like dis...
# 2  Before I get to bulk of what I have to say, I ...
# 3  It is almost the end of the winter, and you've...
# 4  There are still lots of things about space tha...
# 5  Nanahuatl, weakest of the Aztec gods, sickly a...
