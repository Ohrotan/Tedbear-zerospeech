# %% [markdown]
# # TEDscraper Notebook

# %%
import random
import re
import time

from bs4 import BeautifulSoup
import pandas as pd
import requests
from fake_useragent import UserAgent

import requests
from requests import request
from requests.compat import urljoin, urlparse
from requests.exceptions import HTTPError
from urllib.robotparser import RobotFileParser
from requests import Session
import re
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import simplejson

# %%
driver=webdriver.Chrome()

# %%
headers={'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'}

# %%
url='https://www.ted.com/talks?language=en&page=1&sort=newest'
params={'language':'en','page':1,'sort':'newest'}

# %%
driver.get(url)
video=list()
for _ in driver.find_elements_by_class_name('talk-link'):
    video.append(_.find_element_by_css_selector('a').get_attribute('href'))

# %%
driver.close()

# %%
video
# Out:
# ['https://www.ted.com/talks/gareth_gaskell_how_do_our_brains_process_speech?language=en',
#  'https://www.ted.com/talks/ethan_hawke_give_yourself_permission_to_be_creative?language=en',
#  'https://www.ted.com/talks/matt_walker_how_caffeine_and_alcohol_affect_your_sleep?language=en',
#  'https://www.ted.com/talks/iseult_gillespie_the_myth_of_jason_medea_and_the_golden_fleece?language=en',
#  'https://www.ted.com/talks/kwame_owusu_kesse_a_comprehensive_neighborhood_based_response_to_covid_19?language=en',
#  'https://www.ted.com/talks/philip_freeman_the_rise_and_fall_of_the_celtic_warriors?language=en',
#  'https://www.ted.com/talks/tom_teves_a_call_to_end_the_media_coverage_mass_shooters_want?language=en',
#  'https://www.ted.com/talks/alex_gendler_the_egyptian_myth_of_the_death_of_osiris?language=en',
#  'https://www.ted.com/talks/shari_davis_what_if_you_could_help_decide_how_the_government_spends_public_funds?language=en',
#  'https://www.ted.com/talks/nita_mosby_tyler_want_a_more_just_world_be_an_unlikely_ally?language=en',
#  'https://www.ted.com/talks/matt_walker_a_walk_through_the_stages_of_sleep?language=en',
#  'https://www.ted.com/talks/susan_lupack_the_race_to_decode_a_mysterious_language?language=en',
#  'https://www.ted.com/talks/ariel_waldman_the_invisible_life_hidden_beneath_antarctica_s_ice?language=en',
#  'https://www.ted.com/talks/thomas_abt_why_violence_clusters_in_cities_and_how_to_reduce_it?language=en',
#  'https://www.ted.com/talks/steven_anderson_what_makes_volcanoes_erupt?language=en',
#  'https://www.ted.com/talks/christina_agapakis_what_happens_when_biology_becomes_technology?language=en',
#  'https://www.ted.com/talks/ahmad_m_hasnah_rethinking_education_and_celebrating_the_arabic_language?language=en',
#  'https://www.ted.com/talks/rod_phillips_what_happened_when_the_united_states_tried_to_ban_alcohol?language=en',
#  'https://www.ted.com/talks/jane_goodall_every_day_you_live_you_impact_the_planet?language=en',
#  'https://www.ted.com/talks/ali_kashani_a_friendly_autonomous_robot_that_delivers_your_food?language=en',
#  'https://www.ted.com/talks/iseult_gillespie_the_tale_of_the_boy_who_tricked_the_devil?language=en',
#  'https://www.ted.com/talks/pratik_aghor_the_greatest_mathematician_that_never_lived?language=en',
#  'https://www.ted.com/talks/adeola_fayehun_africa_is_a_sleeping_giant_i_m_trying_to_wake_it_up?language=en',
#  'https://www.ted.com/talks/dustin_tahmahkera_the_last_chief_of_the_comanches_and_the_fall_of_an_empire?language=en',
#  'https://www.ted.com/talks/dan_finkel_can_you_solve_the_ragnarok_riddle?language=en',
#  'https://www.ted.com/talks/cameron_morin_what_do_all_languages_have_in_common?language=en',
#  'https://www.ted.com/talks/d_l_stewart_scenes_from_a_black_trans_life?language=en',
#  'https://www.ted.com/talks/titus_kaphar_can_beauty_open_our_hearts_to_difficult_conversations?language=en',
#  'https://www.ted.com/talks/bill_gates_how_the_pandemic_will_shape_the_near_future?language=en',
#  'https://www.ted.com/talks/shekinah_elmore_the_courage_to_live_with_radical_uncertainty?language=en',
#  'https://www.ted.com/talks/aparna_pallavi_what_foods_did_your_ancestors_love?language=en',
#  'https://www.ted.com/talks/tracy_edwards_stop_being_a_bystander_in_your_own_life?language=en',
#  'https://www.ted.com/talks/h_e_ellen_johnson_sirleaf_how_women_will_lead_us_to_freedom_justice_and_peace?language=en',
#  'https://www.ted.com/talks/matt_trombley_the_beauty_and_complexity_of_finding_common_ground?language=en',
#  'https://www.ted.com/talks/jad_abumrad_how_dolly_parton_led_me_to_an_epiphany?language=en',
#  'https://www.ted.com/talks/al_gore_the_new_urgency_of_climate_change?language=en']

# %% [markdown]
# ## Soup Maker

# %%
class SoupMaker:
    """Make soup objects and put your machine to sleep."""
    

    def sleep_short(self):
        """Suspends execution time between 0 - .2 seconds."""
        return time.sleep(random.uniform(0, .2))

    def sleep_two(self):
        """Suspends execution time between .5 - 2 seconds."""
        return time.sleep(random.uniform(.5, 2))
    
    def sleep_five(self):
        """Suspends execution time between 3 - 5 seconds."""
        return time.sleep(random.uniform(3, 5))

    def make_soup(self, url):
        """Returns soup object from a URL."""
        # generate random user-agent
        user_agent = {'User-agent': UserAgent().random}
        # request page and make soup
        page = requests.get(url, headers=user_agent)
        soup = BeautifulSoup(page.content, 'lxml')
        return soup

    def taste_soup(self, soup):
        """Taste test soup object."""
        try:
            taster = soup.title.text
            bad_soup = re.search(r'404: Not Found', taster)
        except AttributeError:
            bad_soup = None
        return bad_soup

# %% [markdown]
# ## CreateCSV

# %%
class CreateCSV(SoupMaker):
    """Create CSVs of TED topics and languages."""

    def create_topics_csv(self):
        """Creates CSV of all topics available from TED."""
        soup = self.make_soup('https://www.ted.com/topics')
        topic_list = []
        topic_tag = soup.find_all(class_='d:b', style='line-height:3;')
        for tag in topic_tag:
            topic = re.sub(r'\s+', '', tag.text)
            topic_list.append(topic)
        topics_series = pd.Series(topic_list, name='Topic')
        topics_series.to_csv('../data/topics.csv', index=False)

    def create_languages_csv(self):
        """Creates CSV of all language codes supported by TED."""
        lang_url = 'https://www.ted.com/participate/translate/our-languages'
        soup = self.make_soup(lang_url)
        lang_list = []
        lang_tags = soup.find_all('div', class_='h9')
        for tag in lang_tags:
            if tag.a == None:
                continue
            else:
                lang_code = re.search(r'(?<=\=)[\w-]+', tag.a['href']).group(0)
                lang_name = tag.text
                lang_list.append([lang_code] + [lang_name])
        lang_df = pd.DataFrame(data=lang_list, columns=['lang_code', 'language'])
        lang_df.to_csv('../data/languages.csv', index=False)

# %% [markdown]
# ## Talk Features

# %%
class TalkFeatures(SoupMaker):
    """Class to get TED talk features."""


    def get_talk_id(self, soup):
        """Returns the talk_id provided by TED."""
        talk_id = re.search(r"(?<=\"current_talk\":)\"(\d+)\"", str(soup)).group(1)
        return talk_id

    def get_title(self, soup):
        """Returns the title of the talk."""
        title_tag = soup.find(attrs={'name': 'title'}).attrs['content']
        tag_list = title_tag.split(':')
        title = ":".join(tag_list[1:]).lstrip()
        return title

    def get_speaker_1(self, soup):
        """Returns the first speaker in TED's speaker list."""
        try:
            speaker_tag = re.findall(r"(?<=\"speakers\":).*?\"}]", str(soup))[0]
            # convert to DataFrame
            speakers_df = pd.read_json(speaker_tag)
            full_name_raw = (speakers_df.loc[:, 'firstname'] + ' '
                         + speakers_df.loc[:, 'middleinitial'] + ' '
                         + speakers_df.loc[:, 'lastname'])
            full_name_clean = full_name_raw.str.replace('\s+', ' ')
            # transform series to a dict
            speaker = full_name_clean.iloc[0]
        except:
            speaker = re.search(r"(?<=\"speaker_name\":)\"(.*?)\"", str(soup)).group(1)
        return speaker

    def get_all_speakers(self, soup):
        """Returns dict of all speakers per talk."""
        try:
            speaker_tag = re.findall(r"(?<=\"speakers\":).*?\"}]", str(soup))[0]
            # convert to DataFrame
            speakers_df = pd.read_json(speaker_tag)
            full_name_raw = (speakers_df.loc[:, 'firstname'] + ' '
                         + speakers_df.loc[:, 'middleinitial'] + ' '
                         + speakers_df.loc[:, 'lastname'])
            full_name_clean = full_name_raw.str.replace('\s+', ' ')
            # transform series to a dict
            speakers = full_name_clean.to_dict()
        except:
            speakers = None
        return speakers

    def get_occupations(self, soup):
        """Returns list of the occupation(s) of the speaker(s) per talk."""
        try:
            occupations_tag = re.findall(r"(?<=\"speakers\":).*?\"}]", str(soup))[0]
            # convert json to DataFrame
            occupations_series = pd.read_json(occupations_tag)['description']
            if occupations_series.all():
                # clean and create dict
                occupations = occupations_series.str.lower().str.split(', ')
                occupations = occupations.to_dict()
            else:
                occupations = None
        except:
            occupations = None
        return occupations

    def get_about_speakers(self, soup):
        """Returns dict with each 'About the Speaker' blurb per talk."""
        try:
            speaker_tag = re.findall(r"(?<=\"speakers\":).*?\"}]", str(soup))[0]
            # convert to DataFrame
            about_series = pd.read_json(speaker_tag)['whotheyare']
            if about_series.all():
                # transform series to a dict
                about_speakers = about_series.to_dict()
            else:
                about_speakers = None
        except:
            about_speakers = None
        return about_speakers

    def get_views(self, soup):
        """Returns viewed count per talk."""
        view_count = re.search(r"(?<=\"viewed_count\":)\d+", str(soup)).group(0)
        return view_count

    def get_recorded_date(self, soup):
        """Returns date a talk was recorded."""
        try:
            tag = re.search(r"(?<=\"recorded_at\":\")[\d-]+", str(soup))
            recorded_at = tag.group(0)
        except:
            recorded_at = None
        return recorded_at

    def get_published_date(self, soup):
        """Returns date a talk was published in TED.com."""
        published_raw = soup.find(attrs={'itemprop': 'uploadDate'}).attrs['content']
        published_date = re.search(r"[\d-]+", published_raw).group(0)
        return published_date

    def get_event(self, soup):
        """Returns name of the event in which the talk was given."""
        event = re.search(r"(?<=\"event\":)\"(.*?)\"", str(soup)).group(1)
        return event
    
    def get_native_lang(self, soup):
        """Returns native language code for each talk as a string."""
        native_lang = re.search(r'(?<=nativeLanguage\":)\"(.*?)\"', str(soup)).group(1)
        return native_lang
    
    def get_available_lang(self, soup):
        """Returns list of all available languages (lang codes) for a talk."""
        languages = re.findall(r'(?<=languageCode\":)\"(.*?)\"', str(soup))
        clean_lang = sorted(list(set(languages)))
        return clean_lang

    def get_comments_count(self, soup):
        """Return the count of comments per talk."""
        try:
            comments_count = re.search(r"(?<=\"count\":)(\d+)", str(soup)).group(1)
        except AttributeError:
            comments_count = None
        return comments_count

    def get_duration(self, soup):
        """Returns duration of a talk in seconds."""
        duration =  re.search(r"(?<=\"duration\":)(\d+)", str(soup)).group(1)
        return duration

    def get_topics(self, soup):
        """Returns list of tags (topics) per talk."""
        match_obj = re.search(r"\"tag\":\"(.*?)\"", str(soup))
        topics = match_obj.group(1).split(',')
        return topics

    def get_related_talks(self, soup):
        """Returns dict (keys: id & title) of related talks."""
        related_tag = re.search(r"(?<=\"related_talks\":).*?]", str(soup)).group(0)
        related_sr = pd.read_json(related_tag)
        related_talks = dict(zip(related_sr['id'], related_sr['title']))
        return related_talks

    def get_talk_url(self, soup):
        """Returns url for each talk as a string."""
        talk_tag = soup.find(attrs={'property': 'og:url'}).attrs['content']
        talk_url = talk_tag.split('transcript')[0]
        return talk_url

    def get_description(self, soup):
        """Returns description of the talk."""
        desc_tag = soup.find(attrs={'property': 'og:description'}).attrs['content']
        talk_desc = desc_tag.split(': ', 1)[1]
        return talk_desc

    def get_transcript(self, soup):
        """Returns talk's transcript as a single string.""" 
        transcript = ''
        transcript_strings = []
        for div in soup.find_all('div', class_="Grid__cell flx-s:1 p-r:4"):
            for p in div.find_all('p'):
                # add every string in the transcript to a list
                transcript_strings.append(" ".join(p.text.split()))
            else:
                # after all strings have been added, create a single transcript string
                transcript = " ".join(transcript_strings)
        return transcript

# %% [markdown]
# ## URLs

# %%
class URLs(SoupMaker):
    """Get and process urls to scrape."""

    
    def topics_url_param(self):
        """Returns string of the url query from topics parameter."""
        topics_param = ''
        if self.topics != 'all':
            if isinstance(self.topics, list):
                for topic in self.topics:
                    topics_param += ('&topics[]=' + topic)
            else:
                raise ValueError("'topics' param needs to be a list")
        return topics_param

    def get_max_page(self):
        """Returns max pagination number from www.ted.com/talks."""
        page_num = [1]
        # make soup from ted.com/talks with specified language
        soup = self.make_soup(self.base_url + '&page=1&sort=newest')
        # iterate through each pagination element and get the max
        page_elem = soup.find_all('a', class_='pagination__item pagination__link')
        for element in page_elem:
            page_num.append(int(element.text))
        return max(page_num)
    
    def get_all_url_paths(self):
        """Returns list of all the talk url paths available in www.ted.com/talks"""
        url_path_list = []
        # construct url with lang code specified by the user
        talks_url = (self.base_url + '&page=')
        # set range from 1 to the max page in the pagination element
        page_range = range(1, self.get_max_page()+1)
        # iterate through each page and get the url for each talk
        for i in page_range:
            # try a second attempt if first attempt fails
            for attempt in range(2):
                try:
                    talks_page_url = talks_url + str(i) + '&sort=newest'
                    soup = self.make_soup(talks_page_url)
                    # delay between searches
                    self.sleep_short()
                    for div in soup.find_all('div', attrs={'class': 'media__image'}):
                        for a in div.find_all('a'):
                            url_path_list.append(a.get('href'))
                except:
                    # delay before continuing to second attempt
                    self.sleep_two()
                # break from attempts loop if no exceptions are raised
                else:
                    break
        return url_path_list

    def get_all_urls(self):
        """Returns list of complete urls for each talk's transcript page."""
        # '/talks/jen_gunter_why_can_t_we_talk_about_periods?language=fa'
        url_list = []
        for url in self.get_all_url_paths():
            url_list.append(('https://www.ted.com'
                             + url.replace(
                                 # to replace
                                 '?language=' + self.lang_code,
                                 # replace with
                                 '/transcript' + '?language=' + self.lang_code)
                            ))
        return url_list
    
    def clean_urls(self, urls):
        """Returns list of clean urls from urls the user inputs."""
        clean_urls = []
        for idx, url in enumerate(urls):
            if url.startswith('https://www.ted.com/talks'):
                parts = url.split('/')
                joined = '/'.join(parts[:5])
                clean = joined.split('?')
                lang = clean[0] + '/transcript?language=' + self.lang_code
                topic = lang + self.topics_url_param()
                clean_urls.append(lang)
            else:
                print(f'bad url @ {idx} >> {url}')
                continue
        return clean_urls
    
    def url_issues(self):
        """Returns DataFrame of urls with known issues."""
        issues_df = pd.read_csv('../data/known_issues.csv')
        return issues_df
    
    def remove_urls_with_issues(self):
        """Remove urls with known issues to prevent unnecessary scraping."""
        urls = self.all_urls()
        final_urls = []
        removed_urls = []
        removed_counter = 0
        issues_df = pd.read_csv('../data/known_issues.csv')
        for url in urls:
            try:
                base_url = url.replace('transcript?language=' + self.lang_code, '')
                # is base url in the issues df?
                url_in_issues = (issues_df['url'] == base_url).any()
                # get the lang_codes of the base_url
                langs = issues_df.loc[issues_df['url'] == base_url, 'lang_code']
                # check if the url in issues_df
                if not url_in_issues:
                    final_urls.append(url)
                # if the url is in issues_df, check if it's for the same lang_code
                elif self.lang_code in langs.any():
                    removed_urls.append(url)
                    removed_counter += 1
                    continue
                else:
                    final_urls.append(url)
            except:
                removed_urls.append(url)
                removed_counter += 1
                continue
        if removed_urls:
            print(f"Removed the following {removed_counter} urls as they have "
                  "known issues:\n", removed_urls, end='\n\n')
        return final_urls

    def all_urls(self):
        """Return all urls based on parameter 'urls' without removing."""
        # define url attribute
        if self.urls == 'all':
            urls = self.get_all_urls()
        else:
            if isinstance(self.urls, list):
                urls = self.clean_urls(self.urls)
            else:
                raise ValueError("'urls' param needs to be a list")
        return urls

    def final_urls(self):
        """Return final urls to fetch."""
        # define url attribute
        if self.force_fetch:
            urls = self.all_urls()
        else:
            urls = self.remove_urls_with_issues()  
        return urls

    def seen_urls(self, url, attempt):
        """Returns attempt depending on seen urls for urls that fail."""
        if url not in self.seen:
            yield url
            seen.add(url)
        # if the url was appended earlier after 2 failed attempts
        # it means this is the last attempt (3)
        elif url in self.seen and attempt == 1:
            attempt = 3
        return attempt

# %% [markdown]
# ## TEDscraper

# %%
class TEDscraper(TalkFeatures, URLs):
    """Gets urls and scrapes TED talk data in the specified language.

    Attributes:
        lang_code (str): Language code. Defaults to 'en'.
        language (str): Language name derived from lang_code.
        urls (list): URLs of talks. Defaults to 'all'.
        topics (list): Talk topics. Defaults to 'all'.
        exclude (bool): Exclude transcript. Defaults to False.
        ted_dict (dict): Dict to store ted talk features after scraping.
        dict_id (int): Index of nested dict in 'ted_dict'.
        failed_counter: Counts urls that failed to get scraped.
    """
 

    def __init__(self, lang_code='en', urls='all', topics='all',
                 force_fetch = False, exclude_transcript=False):
        self.lang_code = lang_code
        self.language = self.convert_lang_code()
        self.urls = urls
        self.topics = topics
        self.exclude = exclude_transcript
        self.ted_dict = {}
        self.dict_id = 0
        self.failed_counter = 0
        self.failed_urls = []
        self.force_fetch = force_fetch
        self.seen = set()
        self.base_url = ('https://www.ted.com/talks'
                         + '?language=' + self.lang_code
                         + self.topics_url_param())

    def scrape_all_features(self, soup):
        """Scrapes all features to a nested dict."""
        # create nested dict
        self.ted_dict[self.dict_id] = {}
        nested_dict = self.ted_dict[self.dict_id]
        # add the features to the nested dict
        nested_dict['talk_id'] = self.get_talk_id(soup)
        nested_dict['title'] = self.get_title(soup)
        nested_dict['speaker_1'] = self.get_speaker_1(soup)
        nested_dict['all_speakers'] = self.get_all_speakers(soup)
        nested_dict['occupations'] = self.get_occupations(soup)
        nested_dict['about_speakers'] = self.get_about_speakers(soup)
        nested_dict['views'] = self.get_views(soup)
        nested_dict['recorded_date'] = self.get_recorded_date(soup)
        nested_dict['published_date'] = self.get_published_date(soup)
        nested_dict['event'] = self.get_event(soup)
        nested_dict['native_lang'] = self.get_native_lang(soup)
        nested_dict['available_lang'] = self.get_available_lang(soup)
        nested_dict['comments'] = self.get_comments_count(soup)
        nested_dict['duration'] = self.get_duration(soup)
        nested_dict['topics'] = self.get_topics(soup)
        nested_dict['related_talks'] = self.get_related_talks(soup)
        nested_dict['url'] = self.get_talk_url(soup)
        nested_dict['description'] = self.get_description(soup)
        # add transcript if param is set to False (default)
        if not self.exclude:
            nested_dict['transcript'] = self.get_transcript(soup)
        return nested_dict

    def get_data(self):
        """Returns nested dictionary of features from each talk's transcript page."""
        print("Fetching urls...\n")
        urls = self.final_urls()
        print(f"Scraping {len(urls)} TED talks in '{self.language}'...")
        print(f"Estimated time to complete is {round((.9*len(urls)/60), 1)} minutes\n")
        # iterate through each TED talk transcript url
        for url in urls:
            # delay between each scrape
            self.sleep_short()
            # try up to three attempts
            for i in range(1, 4):
                # check if url has been seen, if true:
                # it means it previously failed twice so make it the final attempt
                attempt = self.seen_urls(url, i)
                try:
                    # make soup
                    soup = self.make_soup(url)                                        
                    # create nested dict
                    self.ted_dict[self.dict_id] = {}
                    # scrape features and add to a nested dict
                    self.scrape_all_features(soup)
                except Exception as e:
                    # taste if it's a bad soup
                    if self.taste_soup(soup):
                        print(f"[BAD_SOUP] {url}")
                        self.failed_urls.append(url)
                        self.failed_counter += 1
                        break
                    elif attempt == 1:
                        # 3-5 second delay before another attempt
                        self.sleep_five()
                        continue
                    elif attempt == 2:
                        # append the url to 'urls' to try again later
                        urls.append(url)
                        break
                    elif attempt == 3:
                        print(f"[EXCEPTION] {e} {url}")
                        self.failed_counter += 1
                        self.failed_urls.append(url)
                        break
                else:
                    # indicate successful scrape
                    print(f"[OK] {self.dict_id} {url}")
                    # add 1 to create a new nested dict
                    self.dict_id += 1
                    # exit attempts loop
                    break
        # print results
        print(f"""\nTed.com scraping results:
            \n\t• Successful: {self.dict_id}
            \n\t• Failed: {self.failed_counter}\n""")
        if self.failed_counter:
            print(f"Failed to scrape:\n{self.failed_urls}\n")
        return self.ted_dict

    def convert_lang_code(self):
        """Reads languages.csv and returns language.
        Parameters:
            lang_code (str): Language code
        """
        df = pd.read_csv('../data/languages.csv')
        lang_series = df.loc[(df['lang_code'] == self.lang_code), 'language']
        language = lang_series.values[0]
        return language

    def to_dataframe(self, ted_dict):
        """Returns sorted DataFrame object from dict."""
        df = pd.DataFrame.from_dict(ted_dict, orient='index')
        df = df.sort_values(by='published_date')
        sorted_df = df.reset_index(drop=True)
        return sorted_df

# %% [markdown]
# ## Get Data

# %%
# instantiate the scraper & pass in optional arguments
scraper = TEDscraper(lang_code='en', urls=video, topics='all')

# %%
# scrape the data and save it to a dictionary
ted_dict = scraper.get_data()
# Out:
# Fetching urls...
#
# Scraping 36 TED talks in 'English'...
# Estimated time to complete is 0.5 minutes
#
# [OK] 0 https://www.ted.com/talks/gareth_gaskell_how_do_our_brains_process_speech/transcript?language=en
# [OK] 1 https://www.ted.com/talks/ethan_hawke_give_yourself_permission_to_be_creative/transcript?language=en
# [OK] 2 https://www.ted.com/talks/matt_walker_how_caffeine_and_alcohol_affect_your_sleep/transcript?language=en
# [OK] 3 https://www.ted.com/talks/iseult_gillespie_the_myth_of_jason_medea_and_the_golden_fleece/transcript?language=en
# [OK] 4 https://www.ted.com/talks/kwame_owusu_kesse_a_comprehensive_neighborhood_based_response_to_covid_19/transcript?language=en
# [OK] 5 https://www.ted.com/talks/philip_freeman_the_rise_and_fall_of_the_celtic_warriors/transcript?language=en
# [OK] 6 https://www.ted.com/talks/tom_teves_a_call_to_end_the_media_coverage_mass_shooters_want/transcript?language=en
# [OK] 7 https://www.ted.com/talks/alex_gendler_the_egyptian_myth_of_the_death_of_osiris/transcript?language=en
# [OK] 8 https://www.ted.com/talks/shari_davis_what_if_you_could_help_decide_how_the_government_spends_public_funds/transcript?language=en
# [OK] 9 https://www.ted.com/talks/nita_mosby_tyler_want_a_more_just_world_be_an_unlikely_ally/transcript?language=en
# [OK] 10 https://www.ted.com/talks/matt_walker_a_walk_through_the_stages_of_sleep/transcript?language=en
# [OK] 11 https://www.ted.com/talks/susan_lupack_the_race_to_decode_a_mysterious_language/transcript?language=en
# [OK] 12 https://www.ted.com/talks/ariel_waldman_the_invisible_life_hidden_beneath_antarctica_s_ice/transcript?language=en
# [OK] 13 https://www.ted.com/talks/thomas_abt_why_violence_clusters_in_cities_and_how_to_reduce_it/transcript?language=en
# [OK] 14 https://www.ted.com/talks/steven_anderson_what_makes_volcanoes_erupt/transcript?language=en
# [OK] 15 https://www.ted.com/talks/christina_agapakis_what_happens_when_biology_becomes_technology/transcript?language=en
# [OK] 16 https://www.ted.com/talks/ahmad_m_hasnah_rethinking_education_and_celebrating_the_arabic_language/transcript?language=en
# [OK] 17 https://www.ted.com/talks/rod_phillips_what_happened_when_the_united_states_tried_to_ban_alcohol/transcript?language=en
# [OK] 18 https://www.ted.com/talks/jane_goodall_every_day_you_live_you_impact_the_planet/transcript?language=en
# [OK] 19 https://www.ted.com/talks/ali_kashani_a_friendly_autonomous_robot_that_delivers_your_food/transcript?language=en
# [OK] 20 https://www.ted.com/talks/iseult_gillespie_the_tale_of_the_boy_who_tricked_the_devil/transcript?language=en
# [OK] 21 https://www.ted.com/talks/pratik_aghor_the_greatest_mathematician_that_never_lived/transcript?language=en
# [OK] 22 https://www.ted.com/talks/adeola_fayehun_africa_is_a_sleeping_giant_i_m_trying_to_wake_it_up/transcript?language=en
# [OK] 23 https://www.ted.com/talks/dustin_tahmahkera_the_last_chief_of_the_comanches_and_the_fall_of_an_empire/transcript?language=en
# [OK] 24 https://www.ted.com/talks/dan_finkel_can_you_solve_the_ragnarok_riddle/transcript?language=en
# [OK] 25 https://www.ted.com/talks/cameron_morin_what_do_all_languages_have_in_common/transcript?language=en
# [OK] 26 https://www.ted.com/talks/d_l_stewart_scenes_from_a_black_trans_life/transcript?language=en
# [OK] 27 https://www.ted.com/talks/titus_kaphar_can_beauty_open_our_hearts_to_difficult_conversations/transcript?language=en
# [OK] 28 https://www.ted.com/talks/bill_gates_how_the_pandemic_will_shape_the_near_future/transcript?language=en
# [OK] 29 https://www.ted.com/talks/shekinah_elmore_the_courage_to_live_with_radical_uncertainty/transcript?language=en
# [OK] 30 https://www.ted.com/talks/aparna_pallavi_what_foods_did_your_ancestors_love/transcript?language=en
# [OK] 31 https://www.ted.com/talks/tracy_edwards_stop_being_a_bystander_in_your_own_life/transcript?language=en
# [OK] 32 https://www.ted.com/talks/h_e_ellen_johnson_sirleaf_how_women_will_lead_us_to_freedom_justice_and_peace/transcript?language=en
# [OK] 33 https://www.ted.com/talks/matt_trombley_the_beauty_and_complexity_of_finding_common_ground/transcript?language=en
# [OK] 34 https://www.ted.com/talks/jad_abumrad_how_dolly_parton_led_me_to_an_epiphany/transcript?language=en
# [OK] 35 https://www.ted.com/talks/al_gore_the_new_urgency_of_climate_change/transcript?language=en
#
# Ted.com scraping results:
#
# 	• Successful: 36
#
# 	• Failed: 0

# %%
# transform the dictionary to a sorted pandas DataFrame
df2 = scraper.to_dataframe(ted_dict)

# %%
df2
# Out:
#    talk_id                                              title  \
# 0    64693                  The new urgency of climate change
# 1    64534             How Dolly Parton led me to an epiphany
# 2    63727  How women will lead us to freedom, justice and...
# 3    60319  The beauty and complexity of finding common gr...
# 4    64185            Stop being a bystander in your own life
# 5    62845                What foods did your ancestors love?
# 6    63853       The courage to live with radical uncertainty
# 7    64835        How the pandemic will shape the near future
# 8    64776  Can beauty open our hearts to difficult conver...
# 9    64824                     Scenes from a Black trans life
# 10   63654              What do all languages have in common?
# 11   64418                 Can you solve the Ragnarok riddle?
# 12   64208  The last chief of the Comanches and the fall o...
# 13   64886  Africa is a sleeping giant -- I'm trying to wa...
# 14   64585        The greatest mathematician that never lived
# 15   64730          The tale of the boy who tricked the Devil
# 16   64912  A friendly, autonomous robot that delivers you...
# 17   63815          Every day you live, you impact the planet
# 18   64731  What happened when the United States tried to ...
# 19   65030      What happens when biology becomes technology?
# 20   65047                        What makes volcanoes erupt?
# 21   64836  Why violence clusters in cities -- and how to ...
# 22   64916  Rethinking education and celebrating the Arabi...
# 23   63749  The invisible life hidden beneath Antarctica's...
# 24   64915           The race to decode a mysterious language
# 25   65060                 A walk through the stages of sleep
# 26   65043        Want a more just world? Be an unlikely ally
# 27   64914           The Egyptian myth of the death of Osiris
# 28   65045  What if you could help decide how the governme...
# 29   65044  A call to end the media coverage mass shooters...
# 30   65058           The rise and fall of the Celtic warriors
# 31   65074  A comprehensive, neighborhood-based response t...
# 32   65280    The myth of Jason, Medea, and the Golden Fleece
# 33   65061         How caffeine and alcohol affect your sleep
# 34   65073            Give yourself permission to be creative
# 35   65059                  How do our brains process speech?
#
#                 speaker_1                                 all_speakers  \
# 0                 Al Gore          {0: 'Al Gore', 1: 'Chris Anderson'}
# 1             Jad Abumrad                           {0: 'Jad Abumrad'}
# 2   Ellen Johnson Sirleaf                 {0: 'Ellen Johnson Sirleaf'}
# 3           Matt Trombley                         {0: 'Matt Trombley'}
# 4           Tracy Edwards                         {0: 'Tracy Edwards'}
# 5          Aparna Pallavi                        {0: 'Aparna Pallavi'}
# 6         Shekinah Elmore                       {0: 'Shekinah Elmore'}
# 7              Bill Gates       {0: 'Bill Gates', 1: 'Chris Anderson'}
# 8            Titus Kaphar                          {0: 'Titus Kaphar'}
# 9             D-L Stewart                           {0: 'D-L Stewart'}
# 10          Cameron Morin                         {0: 'Cameron Morin'}
# 11             Dan Finkel                            {0: 'Dan Finkel'}
# 12      Dustin Tahmahkera                     {0: 'Dustin Tahmahkera'}
# 13         Adeola Fayehun                        {0: 'Adeola Fayehun'}
# 14           Pratik Aghor                          {0: 'Pratik Aghor'}
# 15       Iseult Gillespie                      {0: 'Iseult Gillespie'}
# 16            Ali Kashani                           {0: 'Ali Kashani'}
# 17           Jane Goodall     {0: 'Jane Goodall', 1: 'Chris Anderson'}
# 18           Rod Phillips                          {0: 'Rod Phillips'}
# 19     Christina Agapakis                    {0: 'Christina Agapakis'}
# 20        Steven Anderson                       {0: 'Steven Anderson'}
# 21             Thomas Abt                            {0: 'Thomas Abt'}
# 22        Ahmad M. Hasnah  {0: 'Ahmad M. Hasnah', 1: 'Bruno Giussani'}
# 23          Ariel Waldman                         {0: 'Ariel Waldman'}
# 24           Susan Lupack                          {0: 'Susan Lupack'}
# 25            Matt Walker                           {0: 'Matt Walker'}
# 26       Nita Mosby Tyler                      {0: 'Nita Mosby Tyler'}
# 27           Alex Gendler                          {0: 'Alex Gendler'}
# 28            Shari Davis                           {0: 'Shari Davis'}
# 29              Tom Teves                             {0: 'Tom Teves'}
# 30         Philip Freeman                        {0: 'Philip Freeman'}
# 31      Kwame Owusu-Kesse                     {0: 'Kwame Owusu-Kesse'}
# 32       Iseult Gillespie                      {0: 'Iseult Gillespie'}
# 33            Matt Walker                           {0: 'Matt Walker'}
# 34            Ethan Hawke                           {0: 'Ethan Hawke'}
# 35         Gareth Gaskell                        {0: 'Gareth Gaskell'}
#
#                                           occupations  \
# 0       {0: ['climate advocate'], 1: ['head of ted']}
# 1                     {0: ['radio host', 'producer']}
# 2            {0: ['global leader', 'nobel laureate']}
# 3           {0: ['maven', 'teacher', 'team builder']}
# 4                                {0: ['trailblazer']}
# 5                                 {0: ['journalist']}
# 6                                 {0: ['oncologist']}
# 7   {0: ['technologist', 'philanthropist'], 1: ['h...
# 8                                     {0: ['artist']}
# 9                       {0: ['scholar and activist']}
# 10                                               None
# 11                                               None
# 12                                               None
# 13                    {0: ['journalist', 'satirist']}
# 14                                               None
# 15                                               None
# 16                 {0: ['designer', 'ai specialist']}
# 17  {0: ['primatologist', 'conservationist'], 1: [...
# 18                                               None
# 19                       {0: ['biological designer']}
# 20                                               None
# 21       {0: ['author', 'researcher', 'policymaker']}
# 22                                               None
# 23        {0: ['antarctic explorer', 'nasa advisor']}
# 24                                               None
# 25    {0: ['sleep scientist', 'professor', 'author']}
# 26                           {0: ['equity advocate']}
# 27                                               None
# 28        {0: ['community leader', 'youth advocate']}
# 29   {0: ['co-founder of the no notoriety campaign']}
# 30                                               None
# 31                          {0: ['community leader']}
# 32                                               None
# 33    {0: ['sleep scientist', 'professor', 'author']}
# 34               {0: ['actor', 'writer', 'director']}
# 35                                               None
#
#                                        about_speakers    views recorded_date  \
# 0   {0: 'Nobel Laureate Al Gore focused the world'...   968368    2020-06-23
# 1   {0: 'As a producer, the creator and host of th...   863968    2020-06-04
# 2   {0: 'The former President of Liberia, Nobel la...   816748    2019-12-04
# 3   {0: 'Matt Trombley is an active, passionate an...   231413    2020-02-05
# 4   {0: 'Tracy Edwards MBE battled against the odd...   991138    2020-05-18
# 5   {0: 'Aparna Pallavi researches and writes abou...   871204    2018-12-08
# 6   {0: 'Shekinah Elmore is dedicated to pursuing ...    96332    2020-03-04
# 7   {0: 'A passionate techie, Bill Gates changed t...  1170738    2020-06-28
# 8   {0: 'Titus Kaphar's artworks interact with the...   110993    2020-06-25
# 9   {0: 'D-L Stewart empowers and imagines futures...   726797    2019-03-09
# 10                                               None   470636    2020-06-29
# 11                                               None  1014394    2020-06-30
# 12                                               None   152063    2020-06-16
# 13  {0: 'Adeola Fayehun combines her passion for a...   741938    2020-05-28
# 14                                               None   877964    2020-07-06
# 15                                               None  1129235    2020-07-07
# 16  {0: 'Ali Kashani explores the unexpected roles...   717409    2020-06-11
# 17  {0: 'Dubbed "the woman who redefined man" by h...   703875    2020-05-18
# 18                                               None   287570    2020-07-09
# 19  {0: 'In her art and scientific work, Christina...   671072    2020-06-11
# 20                                               None   206388    2020-07-13
# 21  {0: 'Thomas Abt developed an innovative, evide...    65966    2020-03-04
# 22  {0: 'Dr. Ahmad M. Hasnah is President of Hamad...        0    2020-06-22
# 23  {0: 'An artist who's pivoted to science, Ariel...   439226    2020-05-18
# 24                                               None   425649    2020-07-14
# 25  {0: 'Matt Walker is a brain scientist trying t...    57721    2020-07-15
# 26  {0: 'Nita Mosby Tyler specializes in the devel...   607605    2019-11-16
# 27                                               None   488941    2020-07-16
# 28  {0: 'As a leader of the Participatory Budgetin...   547410    2020-07-02
# 29  {0: 'Tom Teves urges the leadership of news or...   572231    2019-11-16
# 30                                               None   235358    2020-07-20
# 31  {0: 'Kwame Owusu-Kesse ensures the programming...   515868    2020-06-18
# 32                                               None   183784    2020-07-21
# 33  {0: 'Matt Walker is a brain scientist trying t...    55141    2020-07-22
# 34  {0: '"Ethan Hawke has quietly emerged as perha...   553707    2020-06-25
# 35                                               None   158176    2020-07-23
#
#    published_date                  event native_lang  \
# 0      2020-06-25               TED2020           en
# 1      2020-06-25               TED2020           en
# 2      2020-06-26          TEDWomen 2019          en
# 3      2020-06-26         TED@WellsFargo          en
# 4      2020-06-30               TED2020           en
# 5      2020-06-30      TEDxCapeTownWomen          en
# 6      2020-07-01            TEDMED 2020          en
# 7      2020-07-01               TED2020           en
# 8      2020-07-01               TED2020           en
# 9      2020-07-02                TEDxCSU          en
# 10     2020-07-06                 TED-Ed          en
# 11     2020-07-06                 TED-Ed          en
# 12     2020-07-06                 TED-Ed          en
# 13     2020-07-06               TED2020           en
# 14     2020-07-06                 TED-Ed          en
# 15     2020-07-07                 TED-Ed          en
# 16     2020-07-08               TED2020           en
# 17     2020-07-09               TED2020           en
# 18     2020-07-09                 TED-Ed          en
# 19     2020-07-13               TED2020           en
# 20     2020-07-13                 TED-Ed          en
# 21     2020-07-13            TEDMED 2020          en
# 22     2020-07-13      Build Back Better          en
# 23     2020-07-14               TED2020           en
# 24     2020-07-14                 TED-Ed          en
# 25     2020-07-15  Sleeping with Science          en
# 26     2020-07-15           TEDxMileHigh          en
# 27     2020-07-16                 TED-Ed          en
# 28     2020-07-16               TED2020           en
# 29     2020-07-20           TEDxMileHigh          en
# 30     2020-07-21                 TED-Ed          en
# 31     2020-07-21               TED2020           en
# 32     2020-07-21                 TED-Ed          en
# 33     2020-07-22  Sleeping with Science          en
# 34     2020-07-23               TED2020           en
# 35     2020-07-23                 TED-Ed          en
#
#                                        available_lang comments duration  \
# 0                                            [en, nl]       52     3405
# 1                              [en, pt-br, tr, zh-cn]       26      791
# 2               [ckb, en, es, hi, hr, ku, pt, ro, tr]       16      851
# 3              [ar, el, en, es, fr, pt-br, ro, zh-tw]       16      840
# 4                      [en, hr, my, pt, pt-br, zh-cn]       11      674
# 5              [en, es, fa, mr, pt, pt-br, tr, zh-cn]        6      880
# 6                     [ar, bg, en, fr, ko, ro, zh-tw]        8      953
# 7                                        [en, nl, tr]      117     2587
# 8                                  [en, pt-br, zh-tw]       22      815
# 9                                 [ar, en, fr, pt-br]       21      919
# 10  [en, fa, fr, ja, my, pl, pt, pt-br, ro, tr, zh...     None      302
# 11              [en, fr, pt, pt-br, tr, zh-cn, zh-tw]     None      274
# 12                     [en, hu, pt, pt-br, tr, zh-tw]     None      363
# 13                        [en, mr, ru, tr, uz, zh-tw]       23      429
# 14          [ar, en, my, pt, pt-br, tr, zh-cn, zh-tw]     None      290
# 15  [ar, ckb, en, es, fr, hi, hr, ku, pt, pt-br, z...     None      302
# 16                         [el, en, pt-br, tr, zh-tw]        9      531
# 17                                               [en]       18     1514
# 18                        [en, my, pt, ro, tr, zh-tw]     None      294
# 19                                [en, es, fa, zh-tw]       36      658
# 20                 [en, es, fa, hi, tr, zh-cn, zh-tw]     None      310
# 21                            [en, fr, hr, pt, pt-br]       13      891
# 22                                           [ar, en]     None     1592
# 23                        [ar, en, es, nl, ro, zh-tw]        3      356
# 24                     [en, hu, my, pt-br, tr, zh-tw]     None      264
# 25                                [en, fr, pt-br, tr]        7      287
# 26                            [el, en, fr, hi, zh-cn]        9      615
# 27     [ar, en, es, fr, ja, ku, ro, th, zh-cn, zh-tw]     None      236
# 28                                       [en, fr, hi]       12      628
# 29                                    [el, en, pt-br]        8      867
# 30                                 [en, pt-br, zh-tw]     None      291
# 31                                           [en, tr]        8      396
# 32                                [en, es, fr, zh-tw]     None      269
# 33                                       [en, fr, hi]        5      294
# 34                                       [en, my, ro]       28      556
# 35                               [ckb, en, my, zh-tw]     None      261
#
#                                                topics  \
# 0   [environment, climate change, global issues, e...
# 1   [storytelling, media, arts, relationships, jou...
# 2   [leadership, government, women, gender equalit...
# 3   [humanity, community, communication, personal ...
# 4   [life, adventure, personal growth, identity, s...
# 5   [history, food, indigenous peoples, culture, a...
# 6   [cancer, illness, life, health care, mental he...
# 7   [coronavirus, pandemic, science, public health...
# 8   [art, history, race, painting, social change, ...
# 9   [gender, race, Gender spectrum, Transgender, s...
# 10  [education, TED-Ed, language, animation, speec...
# 11               [TED-Ed, education, math, animation]
# 12  [TED-Ed, animation, education, indigenous peop...
# 13  [Africa, journalism, humor, corruption, activi...
# 14  [math, education, history, TED-Ed, animation, ...
# 15  [TED-Ed, animation, education, storytelling, c...
# 16  [technology, robots, innovation, business, ind...
# 17  [nature, animals, humanity, climate change, co...
# 18  [TED-Ed, animation, government, education, his...
# 19  [science, biology, nature, art, innovation, sc...
# 20  [TED-Ed, education, animation, natural disaste...
# 21  [violence, United States, crime, cities, inequ...
# 22          [education, society, future, Middle East]
# 23  [science, animals, exploration, Antarctica, na...
# 24  [TED-Ed, education, language, animation, ancie...
# 25               [sleep, health, human body, science]
# 26  [activism, inequality, race, social change, TE...
# 27  [education, ancient world, TED-Ed, animation, ...
# 28  [democracy, leadership, community, social chan...
# 29  [violence, guns, big problems, TEDx, activism,...
# 30  [TED-Ed, animation, education, history, war, r...
# 31  [coronavirus, education, community, Audacious ...
# 32  [TED-Ed, education, animation, history, war, v...
# 33               [sleep, science, health, human body]
# 34  [creativity, arts, life, humanity, vulnerabili...
# 35  [education, TED-Ed, speech, animation, neurolo...
#
#                                         related_talks  \
# 0   {2441: 'The case for optimism on climate chang...
# 1   {2665: 'If a story moves you, act on it', 2813...
# 2   {59155: 'How women are revolutionizing Rwanda'...
# 3   {55061: 'The language of being human', 1533: '...
# 4   {60183: '2 questions to uncover your passion -...
# 5   {24455: 'The history of chocolate', 424: 'The ...
# 6   {55027: 'The beautiful balance between courage...
# 7   {61301: 'How we must respond to the coronaviru...
# 8   {2826: 'Can art amend history?', 64511: 'How r...
# 9   {36659: 'A short history of trans people's lon...
# 10  {6857: 'The benefits of a bilingual brain', 24...
# 11  {17849: 'Can you solve the giant cat army ridd...
# 12  {18514: 'Did the Amazons really exist?', 46519...
# 13  {59152: '3 ways to uproot a culture of corrupt...
# 14  {23981: 'The most groundbreaking scientist you...
# 15  {60411: 'The tale of the doctor who defied Dea...
# 16  {59153: 'A fascinating time capsule of human f...
# 17  {340: 'How humans and animals can live togethe...
# 18  {62865: 'What really happened during the Salem...
# 19  {52269: 'Why "biofabrication" is the next indu...
# 20  {24060: 'How tsunamis work', 61316: 'Why isn't...
# 21  {46535: 'How we can make racism a solvable pro...
# 22  {23658: ' How I'm using LEGO to teach Arabic',...
# 23  {2511: 'Drawings that show the beauty and frag...
# 24  {24485: 'The world's most mysterious book', 63...
# 25  {41105: 'Sleep is your superpower', 61900: 'Wh...
# 26  {2629: 'The urgency of intersectionality', 641...
# 27  {59150: 'The Egyptian myth of Isis and the sev...
# 28  {46575: 'How to use family dinner to teach pol...
# 29  {14608: 'A Parkland teacher's homework for us ...
# 30  {48275: 'A day in the life of a Celtic Druid',...
# 31  {63813: 'How to quickly scale up contact traci...
# 32  {46592: 'The myth of Jason and the Argonauts '...
# 33  {65060: 'A walk through the stages of sleep', ...
# 34  {64173: 'How drawing can set you free', 60752:...
# 35  {63654: 'What do all languages have in common?...
#
#                                                   url  \
# 0   https://www.ted.com/talks/al_gore_the_new_urge...
# 1   https://www.ted.com/talks/jad_abumrad_how_doll...
# 2   https://www.ted.com/talks/h_e_ellen_johnson_si...
# 3   https://www.ted.com/talks/matt_trombley_the_be...
# 4   https://www.ted.com/talks/tracy_edwards_stop_b...
# 5   https://www.ted.com/talks/aparna_pallavi_what_...
# 6   https://www.ted.com/talks/shekinah_elmore_the_...
# 7   https://www.ted.com/talks/bill_gates_how_the_p...
# 8   https://www.ted.com/talks/titus_kaphar_can_bea...
# 9   https://www.ted.com/talks/d_l_stewart_scenes_f...
# 10  https://www.ted.com/talks/cameron_morin_what_d...
# 11  https://www.ted.com/talks/dan_finkel_can_you_s...
# 12  https://www.ted.com/talks/dustin_tahmahkera_th...
# 13  https://www.ted.com/talks/adeola_fayehun_afric...
# 14  https://www.ted.com/talks/pratik_aghor_the_gre...
# 15  https://www.ted.com/talks/iseult_gillespie_the...
# 16  https://www.ted.com/talks/ali_kashani_a_friend...
# 17  https://www.ted.com/talks/jane_goodall_every_d...
# 18  https://www.ted.com/talks/rod_phillips_what_ha...
# 19  https://www.ted.com/talks/christina_agapakis_w...
# 20  https://www.ted.com/talks/steven_anderson_what...
# 21  https://www.ted.com/talks/thomas_abt_why_viole...
# 22  https://www.ted.com/talks/ahmad_m_hasnah_rethi...
# 23  https://www.ted.com/talks/ariel_waldman_the_in...
# 24  https://www.ted.com/talks/susan_lupack_the_rac...
# 25  https://www.ted.com/talks/matt_walker_a_walk_t...
# 26  https://www.ted.com/talks/nita_mosby_tyler_wan...
# 27  https://www.ted.com/talks/alex_gendler_the_egy...
# 28  https://www.ted.com/talks/shari_davis_what_if_...
# 29  https://www.ted.com/talks/tom_teves_a_call_to_...
# 30  https://www.ted.com/talks/philip_freeman_the_r...
# 31  https://www.ted.com/talks/kwame_owusu_kesse_a_...
# 32  https://www.ted.com/talks/iseult_gillespie_the...
# 33  https://www.ted.com/talks/matt_walker_how_caff...
# 34  https://www.ted.com/talks/ethan_hawke_give_you...
# 35  https://www.ted.com/talks/gareth_gaskell_how_d...
#
#                                           description  \
# 0   The coronavirus brought much of the world to a...
# 1   How do you end a story? Host of "Radiolab" Jad...
# 2   "I was the first woman president of an African...
# 3   How can we disagree with one another, respectf...
# 4   "Life doesn't go from A to B -- it's messy," s...
# 5   Around the world, Indigenous food cultures van...
# 6   When your future is uncertain, how do you keep...
# 7   Bill Gates talks best (and worst) case scenari...
# 8   An artwork's color or composition can pull you...
# 9   At the crossroads of life and livelihood, scho...
# 10  Language is endlessly variable. Each of us can...
# 11  Ragnarok: The fabled end of the world, when gi...
# 12  Late one night in 1871, a group of riders desc...
# 13  "Africa is like a sleeping giant," says journa...
# 14  When Nicolas Bourbaki applied to the American ...
# 15  In a small town, a proud mother showed off her...
# 16  Meet the friendly robot that could deliver you...
# 17  Legendary primatologist Jane Goodall says that...
# 18  On January 17, 1920, less than one hour after ...
# 19  "We've been promised a future of chrome -- but...
# 20  In February of 1942, Mexican farmer Dionisio P...
# 21  Reducing violence in cities in the US isn't th...
# 22  The pandemic has deepened the need to rethink ...
# 23  In this tour of the microscopic world, explore...
# 24  In the early 1900s, archaeologist Sir Arthur E...
# 25  Did you know you go on a journey every night a...
# 26  A more equal world starts with you. Citing a f...
# 27  Long jealous of his older brother Osiris, the ...
# 28  What if you could help decide how the governme...
# 29  On July 20, 2012, a mass shooting in a movie t...
# 30  One summer evening in 335 BCE, Alexander the G...
# 31  Crisis interventions often focus on a single a...
# 32  In Colchis, the hide of a mystical flying ram ...
# 33  Caffeine wakes you up, and alcohol makes you n...
# 34  Reflecting on moments that shaped his life, ac...
# 35  The average 20-year-old knows between 27,000 a...
#
#                                            transcript
# 0   Chris Anderson: Al, welcome. So look, just six...
# 1   I want to tell you about my search for purpose...
# 2   I was the first woman president of an African ...
# 3   So our story started several years ago, when m...
# 4   Being able to navigate is an extraordinary gif...
# 5   Last year, I was living with this indigenous f...
# 6   What's the worst that could happen? Almost exa...
# 7   Chris Anderson: Welcome, Bill Gates. Bill Gate...
# 8   I believe there is beauty in hearing the voice...
# 9   Hello. Hey. (Laughter) As you just heard, my n...
# 10  Language is endlessly variable. Each of us can...
# 11  Ragnarok. The fabled end of the world, when gi...
# 12  Late one night in 1871, a group of riders desc...
# 13  What's up, people? First of all, I cannot beli...
# 14  When Nicolas Bourbaki applied to the American ...
# 15  In the sun-dappled streets of a small town, a ...
# 16  Food delivery. It's the thing that saves mille...
# 17  Chris Anderson: Dr. Jane Goodall, welcome. Jan...
# 18  On January 17, 1920, six armed men robbed a Ch...
# 19  A briefcase full of poop changed my life. Ten ...
# 20  In February of 1942, Mexican farmer Dionisio P...
# 21  You are a trauma surgeon, working in the midni...
# 22  Hello, I am going to be joined shortly by Dr. ...
# 23  Can you guess what this is? What if I told you...
# 24  In the early 1900s on the island of Crete, Bri...
# 25  Sleep is perhaps the single most effective thi...
# 26  You can ask anyone you want, and they will tel...
# 27  It was a feast like Egypt had never seen befor...
# 28  My name is Shari Davis, and let's be honest, I...
# 29  Every parent's worst nightmare: July 20, 2012,...
# 30  One summer evening in 335 BCE, Alexander the G...
# 31  Good evening. It is such a blessing to work at...
# 32  In the center of Colchis in an enchanted garde...
# 33  Many of us like to start the day with a cup of...
# 34  I was hoping today to talk a little bit about ...
# 35  The average 20 year old knows between 27,000 a...

# %%
# fill NoneType data into int(0)
for i in range(0,len(df2)):
    
    if str(type(df2['comments'][i])) =="<class 'NoneType'>":
        df2['comments'][i]=0
    print(i,type(df2['comments'][i]))
    if str(type(df2['views'][i])) =="<class 'NoneType'>":
        df2['views'][i]=0
# Out:
# 0 <class 'str'>
# 1 <class 'str'>
# 2 <class 'str'>
# 3 <class 'str'>
# 4 <class 'str'>
# 5 <class 'str'>
# 6 <class 'str'>
# 7 <class 'str'>
# 8 <class 'str'>
# 9 <class 'str'>
# 10 <class 'int'>
# 11 <class 'int'>
# 12 <class 'int'>
# 13 <class 'str'>
# 14 <class 'int'>
# 15 <class 'int'>
# 16 <class 'str'>
# 17 <class 'str'>
# 18 <class 'int'>
# 19 <class 'str'>
# 20 <class 'int'>
# 21 <class 'str'>
# 22 <class 'int'>
# 23 <class 'str'>
# 24 <class 'int'>
# 25 <class 'str'>
# 26 <class 'str'>
# 27 <class 'int'>
# 28 <class 'str'>
# 29 <class 'str'>
# 30 <class 'int'>
# 31 <class 'str'>
# 32 <class 'int'>
# 33 <class 'str'>
# 34 <class 'str'>
# 35 <class 'int'>

# %%
# change data type

for i in range(0,len(df2)):
    df2['talk_id'][i]=int(df2['talk_id'][i])
    df2['views'][i]=int(df2['views'][i])
    df2['comments'][i]=int(df2['comments'][i])
    df2['duration'][i]=int(df2['duration'][i])

# %%
df2=df2.sort_values(['talk_id'])

df2
# Out:
#    talk_id                                              title  \
# 3    60319  The beauty and complexity of finding common gr...
# 5    62845                What foods did your ancestors love?
# 10   63654              What do all languages have in common?
# 2    63727  How women will lead us to freedom, justice and...
# 23   63749  The invisible life hidden beneath Antarctica's...
# 17   63815          Every day you live, you impact the planet
# 6    63853       The courage to live with radical uncertainty
# 4    64185            Stop being a bystander in your own life
# 12   64208  The last chief of the Comanches and the fall o...
# 11   64418                 Can you solve the Ragnarok riddle?
# 1    64534             How Dolly Parton led me to an epiphany
# 14   64585        The greatest mathematician that never lived
# 0    64693                  The new urgency of climate change
# 15   64730          The tale of the boy who tricked the Devil
# 18   64731  What happened when the United States tried to ...
# 8    64776  Can beauty open our hearts to difficult conver...
# 9    64824                     Scenes from a Black trans life
# 7    64835        How the pandemic will shape the near future
# 21   64836  Why violence clusters in cities -- and how to ...
# 13   64886  Africa is a sleeping giant -- I'm trying to wa...
# 16   64912  A friendly, autonomous robot that delivers you...
# 27   64914           The Egyptian myth of the death of Osiris
# 24   64915           The race to decode a mysterious language
# 22   64916  Rethinking education and celebrating the Arabi...
# 19   65030      What happens when biology becomes technology?
# 26   65043        Want a more just world? Be an unlikely ally
# 29   65044  A call to end the media coverage mass shooters...
# 28   65045  What if you could help decide how the governme...
# 20   65047                        What makes volcanoes erupt?
# 30   65058           The rise and fall of the Celtic warriors
# 35   65059                  How do our brains process speech?
# 25   65060                 A walk through the stages of sleep
# 33   65061         How caffeine and alcohol affect your sleep
# 34   65073            Give yourself permission to be creative
# 31   65074  A comprehensive, neighborhood-based response t...
# 32   65280    The myth of Jason, Medea, and the Golden Fleece
#
#                 speaker_1                                 all_speakers  \
# 3           Matt Trombley                         {0: 'Matt Trombley'}
# 5          Aparna Pallavi                        {0: 'Aparna Pallavi'}
# 10          Cameron Morin                         {0: 'Cameron Morin'}
# 2   Ellen Johnson Sirleaf                 {0: 'Ellen Johnson Sirleaf'}
# 23          Ariel Waldman                         {0: 'Ariel Waldman'}
# 17           Jane Goodall     {0: 'Jane Goodall', 1: 'Chris Anderson'}
# 6         Shekinah Elmore                       {0: 'Shekinah Elmore'}
# 4           Tracy Edwards                         {0: 'Tracy Edwards'}
# 12      Dustin Tahmahkera                     {0: 'Dustin Tahmahkera'}
# 11             Dan Finkel                            {0: 'Dan Finkel'}
# 1             Jad Abumrad                           {0: 'Jad Abumrad'}
# 14           Pratik Aghor                          {0: 'Pratik Aghor'}
# 0                 Al Gore          {0: 'Al Gore', 1: 'Chris Anderson'}
# 15       Iseult Gillespie                      {0: 'Iseult Gillespie'}
# 18           Rod Phillips                          {0: 'Rod Phillips'}
# 8            Titus Kaphar                          {0: 'Titus Kaphar'}
# 9             D-L Stewart                           {0: 'D-L Stewart'}
# 7              Bill Gates       {0: 'Bill Gates', 1: 'Chris Anderson'}
# 21             Thomas Abt                            {0: 'Thomas Abt'}
# 13         Adeola Fayehun                        {0: 'Adeola Fayehun'}
# 16            Ali Kashani                           {0: 'Ali Kashani'}
# 27           Alex Gendler                          {0: 'Alex Gendler'}
# 24           Susan Lupack                          {0: 'Susan Lupack'}
# 22        Ahmad M. Hasnah  {0: 'Ahmad M. Hasnah', 1: 'Bruno Giussani'}
# 19     Christina Agapakis                    {0: 'Christina Agapakis'}
# 26       Nita Mosby Tyler                      {0: 'Nita Mosby Tyler'}
# 29              Tom Teves                             {0: 'Tom Teves'}
# 28            Shari Davis                           {0: 'Shari Davis'}
# 20        Steven Anderson                       {0: 'Steven Anderson'}
# 30         Philip Freeman                        {0: 'Philip Freeman'}
# 35         Gareth Gaskell                        {0: 'Gareth Gaskell'}
# 25            Matt Walker                           {0: 'Matt Walker'}
# 33            Matt Walker                           {0: 'Matt Walker'}
# 34            Ethan Hawke                           {0: 'Ethan Hawke'}
# 31      Kwame Owusu-Kesse                     {0: 'Kwame Owusu-Kesse'}
# 32       Iseult Gillespie                      {0: 'Iseult Gillespie'}
#
#                                           occupations  \
# 3           {0: ['maven', 'teacher', 'team builder']}
# 5                                 {0: ['journalist']}
# 10                                               None
# 2            {0: ['global leader', 'nobel laureate']}
# 23        {0: ['antarctic explorer', 'nasa advisor']}
# 17  {0: ['primatologist', 'conservationist'], 1: [...
# 6                                 {0: ['oncologist']}
# 4                                {0: ['trailblazer']}
# 12                                               None
# 11                                               None
# 1                     {0: ['radio host', 'producer']}
# 14                                               None
# 0       {0: ['climate advocate'], 1: ['head of ted']}
# 15                                               None
# 18                                               None
# 8                                     {0: ['artist']}
# 9                       {0: ['scholar and activist']}
# 7   {0: ['technologist', 'philanthropist'], 1: ['h...
# 21       {0: ['author', 'researcher', 'policymaker']}
# 13                    {0: ['journalist', 'satirist']}
# 16                 {0: ['designer', 'ai specialist']}
# 27                                               None
# 24                                               None
# 22                                               None
# 19                       {0: ['biological designer']}
# 26                           {0: ['equity advocate']}
# 29   {0: ['co-founder of the no notoriety campaign']}
# 28        {0: ['community leader', 'youth advocate']}
# 20                                               None
# 30                                               None
# 35                                               None
# 25    {0: ['sleep scientist', 'professor', 'author']}
# 33    {0: ['sleep scientist', 'professor', 'author']}
# 34               {0: ['actor', 'writer', 'director']}
# 31                          {0: ['community leader']}
# 32                                               None
#
#                                        about_speakers    views recorded_date  \
# 3   {0: 'Matt Trombley is an active, passionate an...   231413    2020-02-05
# 5   {0: 'Aparna Pallavi researches and writes abou...   871204    2018-12-08
# 10                                               None   470636    2020-06-29
# 2   {0: 'The former President of Liberia, Nobel la...   816748    2019-12-04
# 23  {0: 'An artist who's pivoted to science, Ariel...   439226    2020-05-18
# 17  {0: 'Dubbed "the woman who redefined man" by h...   703875    2020-05-18
# 6   {0: 'Shekinah Elmore is dedicated to pursuing ...    96332    2020-03-04
# 4   {0: 'Tracy Edwards MBE battled against the odd...   991138    2020-05-18
# 12                                               None   152063    2020-06-16
# 11                                               None  1014394    2020-06-30
# 1   {0: 'As a producer, the creator and host of th...   863968    2020-06-04
# 14                                               None   877964    2020-07-06
# 0   {0: 'Nobel Laureate Al Gore focused the world'...   968368    2020-06-23
# 15                                               None  1129235    2020-07-07
# 18                                               None   287570    2020-07-09
# 8   {0: 'Titus Kaphar's artworks interact with the...   110993    2020-06-25
# 9   {0: 'D-L Stewart empowers and imagines futures...   726797    2019-03-09
# 7   {0: 'A passionate techie, Bill Gates changed t...  1170738    2020-06-28
# 21  {0: 'Thomas Abt developed an innovative, evide...    65966    2020-03-04
# 13  {0: 'Adeola Fayehun combines her passion for a...   741938    2020-05-28
# 16  {0: 'Ali Kashani explores the unexpected roles...   717409    2020-06-11
# 27                                               None   488941    2020-07-16
# 24                                               None   425649    2020-07-14
# 22  {0: 'Dr. Ahmad M. Hasnah is President of Hamad...        0    2020-06-22
# 19  {0: 'In her art and scientific work, Christina...   671072    2020-06-11
# 26  {0: 'Nita Mosby Tyler specializes in the devel...   607605    2019-11-16
# 29  {0: 'Tom Teves urges the leadership of news or...   572231    2019-11-16
# 28  {0: 'As a leader of the Participatory Budgetin...   547410    2020-07-02
# 20                                               None   206388    2020-07-13
# 30                                               None   235358    2020-07-20
# 35                                               None   158176    2020-07-23
# 25  {0: 'Matt Walker is a brain scientist trying t...    57721    2020-07-15
# 33  {0: 'Matt Walker is a brain scientist trying t...    55141    2020-07-22
# 34  {0: '"Ethan Hawke has quietly emerged as perha...   553707    2020-06-25
# 31  {0: 'Kwame Owusu-Kesse ensures the programming...   515868    2020-06-18
# 32                                               None   183784    2020-07-21
#
#    published_date                  event native_lang  \
# 3      2020-06-26         TED@WellsFargo          en
# 5      2020-06-30      TEDxCapeTownWomen          en
# 10     2020-07-06                 TED-Ed          en
# 2      2020-06-26          TEDWomen 2019          en
# 23     2020-07-14               TED2020           en
# 17     2020-07-09               TED2020           en
# 6      2020-07-01            TEDMED 2020          en
# 4      2020-06-30               TED2020           en
# 12     2020-07-06                 TED-Ed          en
# 11     2020-07-06                 TED-Ed          en
# 1      2020-06-25               TED2020           en
# 14     2020-07-06                 TED-Ed          en
# 0      2020-06-25               TED2020           en
# 15     2020-07-07                 TED-Ed          en
# 18     2020-07-09                 TED-Ed          en
# 8      2020-07-01               TED2020           en
# 9      2020-07-02                TEDxCSU          en
# 7      2020-07-01               TED2020           en
# 21     2020-07-13            TEDMED 2020          en
# 13     2020-07-06               TED2020           en
# 16     2020-07-08               TED2020           en
# 27     2020-07-16                 TED-Ed          en
# 24     2020-07-14                 TED-Ed          en
# 22     2020-07-13      Build Back Better          en
# 19     2020-07-13               TED2020           en
# 26     2020-07-15           TEDxMileHigh          en
# 29     2020-07-20           TEDxMileHigh          en
# 28     2020-07-16               TED2020           en
# 20     2020-07-13                 TED-Ed          en
# 30     2020-07-21                 TED-Ed          en
# 35     2020-07-23                 TED-Ed          en
# 25     2020-07-15  Sleeping with Science          en
# 33     2020-07-22  Sleeping with Science          en
# 34     2020-07-23               TED2020           en
# 31     2020-07-21               TED2020           en
# 32     2020-07-21                 TED-Ed          en
#
#                                        available_lang comments duration  \
# 3              [ar, el, en, es, fr, pt-br, ro, zh-tw]       16      840
# 5              [en, es, fa, mr, pt, pt-br, tr, zh-cn]        6      880
# 10  [en, fa, fr, ja, my, pl, pt, pt-br, ro, tr, zh...        0      302
# 2               [ckb, en, es, hi, hr, ku, pt, ro, tr]       16      851
# 23                        [ar, en, es, nl, ro, zh-tw]        3      356
# 17                                               [en]       18     1514
# 6                     [ar, bg, en, fr, ko, ro, zh-tw]        8      953
# 4                      [en, hr, my, pt, pt-br, zh-cn]       11      674
# 12                     [en, hu, pt, pt-br, tr, zh-tw]        0      363
# 11              [en, fr, pt, pt-br, tr, zh-cn, zh-tw]        0      274
# 1                              [en, pt-br, tr, zh-cn]       26      791
# 14          [ar, en, my, pt, pt-br, tr, zh-cn, zh-tw]        0      290
# 0                                            [en, nl]       52     3405
# 15  [ar, ckb, en, es, fr, hi, hr, ku, pt, pt-br, z...        0      302
# 18                        [en, my, pt, ro, tr, zh-tw]        0      294
# 8                                  [en, pt-br, zh-tw]       22      815
# 9                                 [ar, en, fr, pt-br]       21      919
# 7                                        [en, nl, tr]      117     2587
# 21                            [en, fr, hr, pt, pt-br]       13      891
# 13                        [en, mr, ru, tr, uz, zh-tw]       23      429
# 16                         [el, en, pt-br, tr, zh-tw]        9      531
# 27     [ar, en, es, fr, ja, ku, ro, th, zh-cn, zh-tw]        0      236
# 24                     [en, hu, my, pt-br, tr, zh-tw]        0      264
# 22                                           [ar, en]        0     1592
# 19                                [en, es, fa, zh-tw]       36      658
# 26                            [el, en, fr, hi, zh-cn]        9      615
# 29                                    [el, en, pt-br]        8      867
# 28                                       [en, fr, hi]       12      628
# 20                 [en, es, fa, hi, tr, zh-cn, zh-tw]        0      310
# 30                                 [en, pt-br, zh-tw]        0      291
# 35                               [ckb, en, my, zh-tw]        0      261
# 25                                [en, fr, pt-br, tr]        7      287
# 33                                       [en, fr, hi]        5      294
# 34                                       [en, my, ro]       28      556
# 31                                           [en, tr]        8      396
# 32                                [en, es, fr, zh-tw]        0      269
#
#                                                topics  \
# 3   [humanity, community, communication, personal ...
# 5   [history, food, indigenous peoples, culture, a...
# 10  [education, TED-Ed, language, animation, speec...
# 2   [leadership, government, women, gender equalit...
# 23  [science, animals, exploration, Antarctica, na...
# 17  [nature, animals, humanity, climate change, co...
# 6   [cancer, illness, life, health care, mental he...
# 4   [life, adventure, personal growth, identity, s...
# 12  [TED-Ed, animation, education, indigenous peop...
# 11               [TED-Ed, education, math, animation]
# 1   [storytelling, media, arts, relationships, jou...
# 14  [math, education, history, TED-Ed, animation, ...
# 0   [environment, climate change, global issues, e...
# 15  [TED-Ed, animation, education, storytelling, c...
# 18  [TED-Ed, animation, government, education, his...
# 8   [art, history, race, painting, social change, ...
# 9   [gender, race, Gender spectrum, Transgender, s...
# 7   [coronavirus, pandemic, science, public health...
# 21  [violence, United States, crime, cities, inequ...
# 13  [Africa, journalism, humor, corruption, activi...
# 16  [technology, robots, innovation, business, ind...
# 27  [education, ancient world, TED-Ed, animation, ...
# 24  [TED-Ed, education, language, animation, ancie...
# 22          [education, society, future, Middle East]
# 19  [science, biology, nature, art, innovation, sc...
# 26  [activism, inequality, race, social change, TE...
# 29  [violence, guns, big problems, TEDx, activism,...
# 28  [democracy, leadership, community, social chan...
# 20  [TED-Ed, education, animation, natural disaste...
# 30  [TED-Ed, animation, education, history, war, r...
# 35  [education, TED-Ed, speech, animation, neurolo...
# 25               [sleep, health, human body, science]
# 33               [sleep, science, health, human body]
# 34  [creativity, arts, life, humanity, vulnerabili...
# 31  [coronavirus, education, community, Audacious ...
# 32  [TED-Ed, education, animation, history, war, v...
#
#                                         related_talks  \
# 3   {55061: 'The language of being human', 1533: '...
# 5   {24455: 'The history of chocolate', 424: 'The ...
# 10  {6857: 'The benefits of a bilingual brain', 24...
# 2   {59155: 'How women are revolutionizing Rwanda'...
# 23  {2511: 'Drawings that show the beauty and frag...
# 17  {340: 'How humans and animals can live togethe...
# 6   {55027: 'The beautiful balance between courage...
# 4   {60183: '2 questions to uncover your passion -...
# 12  {18514: 'Did the Amazons really exist?', 46519...
# 11  {17849: 'Can you solve the giant cat army ridd...
# 1   {2665: 'If a story moves you, act on it', 2813...
# 14  {23981: 'The most groundbreaking scientist you...
# 0   {2441: 'The case for optimism on climate chang...
# 15  {60411: 'The tale of the doctor who defied Dea...
# 18  {62865: 'What really happened during the Salem...
# 8   {2826: 'Can art amend history?', 64511: 'How r...
# 9   {36659: 'A short history of trans people's lon...
# 7   {61301: 'How we must respond to the coronaviru...
# 21  {46535: 'How we can make racism a solvable pro...
# 13  {59152: '3 ways to uproot a culture of corrupt...
# 16  {59153: 'A fascinating time capsule of human f...
# 27  {59150: 'The Egyptian myth of Isis and the sev...
# 24  {24485: 'The world's most mysterious book', 63...
# 22  {23658: ' How I'm using LEGO to teach Arabic',...
# 19  {52269: 'Why "biofabrication" is the next indu...
# 26  {2629: 'The urgency of intersectionality', 641...
# 29  {14608: 'A Parkland teacher's homework for us ...
# 28  {46575: 'How to use family dinner to teach pol...
# 20  {24060: 'How tsunamis work', 61316: 'Why isn't...
# 30  {48275: 'A day in the life of a Celtic Druid',...
# 35  {63654: 'What do all languages have in common?...
# 25  {41105: 'Sleep is your superpower', 61900: 'Wh...
# 33  {65060: 'A walk through the stages of sleep', ...
# 34  {64173: 'How drawing can set you free', 60752:...
# 31  {63813: 'How to quickly scale up contact traci...
# 32  {46592: 'The myth of Jason and the Argonauts '...
#
#                                                   url  \
# 3   https://www.ted.com/talks/matt_trombley_the_be...
# 5   https://www.ted.com/talks/aparna_pallavi_what_...
# 10  https://www.ted.com/talks/cameron_morin_what_d...
# 2   https://www.ted.com/talks/h_e_ellen_johnson_si...
# 23  https://www.ted.com/talks/ariel_waldman_the_in...
# 17  https://www.ted.com/talks/jane_goodall_every_d...
# 6   https://www.ted.com/talks/shekinah_elmore_the_...
# 4   https://www.ted.com/talks/tracy_edwards_stop_b...
# 12  https://www.ted.com/talks/dustin_tahmahkera_th...
# 11  https://www.ted.com/talks/dan_finkel_can_you_s...
# 1   https://www.ted.com/talks/jad_abumrad_how_doll...
# 14  https://www.ted.com/talks/pratik_aghor_the_gre...
# 0   https://www.ted.com/talks/al_gore_the_new_urge...
# 15  https://www.ted.com/talks/iseult_gillespie_the...
# 18  https://www.ted.com/talks/rod_phillips_what_ha...
# 8   https://www.ted.com/talks/titus_kaphar_can_bea...
# 9   https://www.ted.com/talks/d_l_stewart_scenes_f...
# 7   https://www.ted.com/talks/bill_gates_how_the_p...
# 21  https://www.ted.com/talks/thomas_abt_why_viole...
# 13  https://www.ted.com/talks/adeola_fayehun_afric...
# 16  https://www.ted.com/talks/ali_kashani_a_friend...
# 27  https://www.ted.com/talks/alex_gendler_the_egy...
# 24  https://www.ted.com/talks/susan_lupack_the_rac...
# 22  https://www.ted.com/talks/ahmad_m_hasnah_rethi...
# 19  https://www.ted.com/talks/christina_agapakis_w...
# 26  https://www.ted.com/talks/nita_mosby_tyler_wan...
# 29  https://www.ted.com/talks/tom_teves_a_call_to_...
# 28  https://www.ted.com/talks/shari_davis_what_if_...
# 20  https://www.ted.com/talks/steven_anderson_what...
# 30  https://www.ted.com/talks/philip_freeman_the_r...
# 35  https://www.ted.com/talks/gareth_gaskell_how_d...
# 25  https://www.ted.com/talks/matt_walker_a_walk_t...
# 33  https://www.ted.com/talks/matt_walker_how_caff...
# 34  https://www.ted.com/talks/ethan_hawke_give_you...
# 31  https://www.ted.com/talks/kwame_owusu_kesse_a_...
# 32  https://www.ted.com/talks/iseult_gillespie_the...
#
#                                           description  \
# 3   How can we disagree with one another, respectf...
# 5   Around the world, Indigenous food cultures van...
# 10  Language is endlessly variable. Each of us can...
# 2   "I was the first woman president of an African...
# 23  In this tour of the microscopic world, explore...
# 17  Legendary primatologist Jane Goodall says that...
# 6   When your future is uncertain, how do you keep...
# 4   "Life doesn't go from A to B -- it's messy," s...
# 12  Late one night in 1871, a group of riders desc...
# 11  Ragnarok: The fabled end of the world, when gi...
# 1   How do you end a story? Host of "Radiolab" Jad...
# 14  When Nicolas Bourbaki applied to the American ...
# 0   The coronavirus brought much of the world to a...
# 15  In a small town, a proud mother showed off her...
# 18  On January 17, 1920, less than one hour after ...
# 8   An artwork's color or composition can pull you...
# 9   At the crossroads of life and livelihood, scho...
# 7   Bill Gates talks best (and worst) case scenari...
# 21  Reducing violence in cities in the US isn't th...
# 13  "Africa is like a sleeping giant," says journa...
# 16  Meet the friendly robot that could deliver you...
# 27  Long jealous of his older brother Osiris, the ...
# 24  In the early 1900s, archaeologist Sir Arthur E...
# 22  The pandemic has deepened the need to rethink ...
# 19  "We've been promised a future of chrome -- but...
# 26  A more equal world starts with you. Citing a f...
# 29  On July 20, 2012, a mass shooting in a movie t...
# 28  What if you could help decide how the governme...
# 20  In February of 1942, Mexican farmer Dionisio P...
# 30  One summer evening in 335 BCE, Alexander the G...
# 35  The average 20-year-old knows between 27,000 a...
# 25  Did you know you go on a journey every night a...
# 33  Caffeine wakes you up, and alcohol makes you n...
# 34  Reflecting on moments that shaped his life, ac...
# 31  Crisis interventions often focus on a single a...
# 32  In Colchis, the hide of a mystical flying ram ...
#
#                                            transcript
# 3   So our story started several years ago, when m...
# 5   Last year, I was living with this indigenous f...
# 10  Language is endlessly variable. Each of us can...
# 2   I was the first woman president of an African ...
# 23  Can you guess what this is? What if I told you...
# 17  Chris Anderson: Dr. Jane Goodall, welcome. Jan...
# 6   What's the worst that could happen? Almost exa...
# 4   Being able to navigate is an extraordinary gif...
# 12  Late one night in 1871, a group of riders desc...
# 11  Ragnarok. The fabled end of the world, when gi...
# 1   I want to tell you about my search for purpose...
# 14  When Nicolas Bourbaki applied to the American ...
# 0   Chris Anderson: Al, welcome. So look, just six...
# 15  In the sun-dappled streets of a small town, a ...
# 18  On January 17, 1920, six armed men robbed a Ch...
# 8   I believe there is beauty in hearing the voice...
# 9   Hello. Hey. (Laughter) As you just heard, my n...
# 7   Chris Anderson: Welcome, Bill Gates. Bill Gate...
# 21  You are a trauma surgeon, working in the midni...
# 13  What's up, people? First of all, I cannot beli...
# 16  Food delivery. It's the thing that saves mille...
# 27  It was a feast like Egypt had never seen befor...
# 24  In the early 1900s on the island of Crete, Bri...
# 22  Hello, I am going to be joined shortly by Dr. ...
# 19  A briefcase full of poop changed my life. Ten ...
# 26  You can ask anyone you want, and they will tel...
# 29  Every parent's worst nightmare: July 20, 2012,...
# 28  My name is Shari Davis, and let's be honest, I...
# 20  In February of 1942, Mexican farmer Dionisio P...
# 30  One summer evening in 335 BCE, Alexander the G...
# 35  The average 20 year old knows between 27,000 a...
# 25  Sleep is perhaps the single most effective thi...
# 33  Many of us like to start the day with a cup of...
# 34  I was hoping today to talk a little bit about ...
# 31  Good evening. It is such a blessing to work at...
# 32  In the center of Colchis in an enchanted garde...

# %%
# output DataFrame as CSV
df2.to_csv('../data/ted_talksVideo.csv', index=False)

# %%
df2
# Out:
#    talk_id                                              title  \
# 3    60319  The beauty and complexity of finding common gr...
# 5    62845                What foods did your ancestors love?
# 10   63654              What do all languages have in common?
# 2    63727  How women will lead us to freedom, justice and...
# 23   63749  The invisible life hidden beneath Antarctica's...
# 17   63815          Every day you live, you impact the planet
# 6    63853       The courage to live with radical uncertainty
# 4    64185            Stop being a bystander in your own life
# 12   64208  The last chief of the Comanches and the fall o...
# 11   64418                 Can you solve the Ragnarok riddle?
# 1    64534             How Dolly Parton led me to an epiphany
# 14   64585        The greatest mathematician that never lived
# 0    64693                  The new urgency of climate change
# 15   64730          The tale of the boy who tricked the Devil
# 18   64731  What happened when the United States tried to ...
# 8    64776  Can beauty open our hearts to difficult conver...
# 9    64824                     Scenes from a Black trans life
# 7    64835        How the pandemic will shape the near future
# 21   64836  Why violence clusters in cities -- and how to ...
# 13   64886  Africa is a sleeping giant -- I'm trying to wa...
# 16   64912  A friendly, autonomous robot that delivers you...
# 27   64914           The Egyptian myth of the death of Osiris
# 24   64915           The race to decode a mysterious language
# 22   64916  Rethinking education and celebrating the Arabi...
# 19   65030      What happens when biology becomes technology?
# 26   65043        Want a more just world? Be an unlikely ally
# 29   65044  A call to end the media coverage mass shooters...
# 28   65045  What if you could help decide how the governme...
# 20   65047                        What makes volcanoes erupt?
# 30   65058           The rise and fall of the Celtic warriors
# 35   65059                  How do our brains process speech?
# 25   65060                 A walk through the stages of sleep
# 33   65061         How caffeine and alcohol affect your sleep
# 34   65073            Give yourself permission to be creative
# 31   65074  A comprehensive, neighborhood-based response t...
# 32   65280    The myth of Jason, Medea, and the Golden Fleece
#
#                 speaker_1                                 all_speakers  \
# 3           Matt Trombley                         {0: 'Matt Trombley'}
# 5          Aparna Pallavi                        {0: 'Aparna Pallavi'}
# 10          Cameron Morin                         {0: 'Cameron Morin'}
# 2   Ellen Johnson Sirleaf                 {0: 'Ellen Johnson Sirleaf'}
# 23          Ariel Waldman                         {0: 'Ariel Waldman'}
# 17           Jane Goodall     {0: 'Jane Goodall', 1: 'Chris Anderson'}
# 6         Shekinah Elmore                       {0: 'Shekinah Elmore'}
# 4           Tracy Edwards                         {0: 'Tracy Edwards'}
# 12      Dustin Tahmahkera                     {0: 'Dustin Tahmahkera'}
# 11             Dan Finkel                            {0: 'Dan Finkel'}
# 1             Jad Abumrad                           {0: 'Jad Abumrad'}
# 14           Pratik Aghor                          {0: 'Pratik Aghor'}
# 0                 Al Gore          {0: 'Al Gore', 1: 'Chris Anderson'}
# 15       Iseult Gillespie                      {0: 'Iseult Gillespie'}
# 18           Rod Phillips                          {0: 'Rod Phillips'}
# 8            Titus Kaphar                          {0: 'Titus Kaphar'}
# 9             D-L Stewart                           {0: 'D-L Stewart'}
# 7              Bill Gates       {0: 'Bill Gates', 1: 'Chris Anderson'}
# 21             Thomas Abt                            {0: 'Thomas Abt'}
# 13         Adeola Fayehun                        {0: 'Adeola Fayehun'}
# 16            Ali Kashani                           {0: 'Ali Kashani'}
# 27           Alex Gendler                          {0: 'Alex Gendler'}
# 24           Susan Lupack                          {0: 'Susan Lupack'}
# 22        Ahmad M. Hasnah  {0: 'Ahmad M. Hasnah', 1: 'Bruno Giussani'}
# 19     Christina Agapakis                    {0: 'Christina Agapakis'}
# 26       Nita Mosby Tyler                      {0: 'Nita Mosby Tyler'}
# 29              Tom Teves                             {0: 'Tom Teves'}
# 28            Shari Davis                           {0: 'Shari Davis'}
# 20        Steven Anderson                       {0: 'Steven Anderson'}
# 30         Philip Freeman                        {0: 'Philip Freeman'}
# 35         Gareth Gaskell                        {0: 'Gareth Gaskell'}
# 25            Matt Walker                           {0: 'Matt Walker'}
# 33            Matt Walker                           {0: 'Matt Walker'}
# 34            Ethan Hawke                           {0: 'Ethan Hawke'}
# 31      Kwame Owusu-Kesse                     {0: 'Kwame Owusu-Kesse'}
# 32       Iseult Gillespie                      {0: 'Iseult Gillespie'}
#
#                                           occupations  \
# 3           {0: ['maven', 'teacher', 'team builder']}
# 5                                 {0: ['journalist']}
# 10                                               None
# 2            {0: ['global leader', 'nobel laureate']}
# 23        {0: ['antarctic explorer', 'nasa advisor']}
# 17  {0: ['primatologist', 'conservationist'], 1: [...
# 6                                 {0: ['oncologist']}
# 4                                {0: ['trailblazer']}
# 12                                               None
# 11                                               None
# 1                     {0: ['radio host', 'producer']}
# 14                                               None
# 0       {0: ['climate advocate'], 1: ['head of ted']}
# 15                                               None
# 18                                               None
# 8                                     {0: ['artist']}
# 9                       {0: ['scholar and activist']}
# 7   {0: ['technologist', 'philanthropist'], 1: ['h...
# 21       {0: ['author', 'researcher', 'policymaker']}
# 13                    {0: ['journalist', 'satirist']}
# 16                 {0: ['designer', 'ai specialist']}
# 27                                               None
# 24                                               None
# 22                                               None
# 19                       {0: ['biological designer']}
# 26                           {0: ['equity advocate']}
# 29   {0: ['co-founder of the no notoriety campaign']}
# 28        {0: ['community leader', 'youth advocate']}
# 20                                               None
# 30                                               None
# 35                                               None
# 25    {0: ['sleep scientist', 'professor', 'author']}
# 33    {0: ['sleep scientist', 'professor', 'author']}
# 34               {0: ['actor', 'writer', 'director']}
# 31                          {0: ['community leader']}
# 32                                               None
#
#                                        about_speakers    views recorded_date  \
# 3   {0: 'Matt Trombley is an active, passionate an...   231413    2020-02-05
# 5   {0: 'Aparna Pallavi researches and writes abou...   871204    2018-12-08
# 10                                               None   470636    2020-06-29
# 2   {0: 'The former President of Liberia, Nobel la...   816748    2019-12-04
# 23  {0: 'An artist who's pivoted to science, Ariel...   439226    2020-05-18
# 17  {0: 'Dubbed "the woman who redefined man" by h...   703875    2020-05-18
# 6   {0: 'Shekinah Elmore is dedicated to pursuing ...    96332    2020-03-04
# 4   {0: 'Tracy Edwards MBE battled against the odd...   991138    2020-05-18
# 12                                               None   152063    2020-06-16
# 11                                               None  1014394    2020-06-30
# 1   {0: 'As a producer, the creator and host of th...   863968    2020-06-04
# 14                                               None   877964    2020-07-06
# 0   {0: 'Nobel Laureate Al Gore focused the world'...   968368    2020-06-23
# 15                                               None  1129235    2020-07-07
# 18                                               None   287570    2020-07-09
# 8   {0: 'Titus Kaphar's artworks interact with the...   110993    2020-06-25
# 9   {0: 'D-L Stewart empowers and imagines futures...   726797    2019-03-09
# 7   {0: 'A passionate techie, Bill Gates changed t...  1170738    2020-06-28
# 21  {0: 'Thomas Abt developed an innovative, evide...    65966    2020-03-04
# 13  {0: 'Adeola Fayehun combines her passion for a...   741938    2020-05-28
# 16  {0: 'Ali Kashani explores the unexpected roles...   717409    2020-06-11
# 27                                               None   488941    2020-07-16
# 24                                               None   425649    2020-07-14
# 22  {0: 'Dr. Ahmad M. Hasnah is President of Hamad...        0    2020-06-22
# 19  {0: 'In her art and scientific work, Christina...   671072    2020-06-11
# 26  {0: 'Nita Mosby Tyler specializes in the devel...   607605    2019-11-16
# 29  {0: 'Tom Teves urges the leadership of news or...   572231    2019-11-16
# 28  {0: 'As a leader of the Participatory Budgetin...   547410    2020-07-02
# 20                                               None   206388    2020-07-13
# 30                                               None   235358    2020-07-20
# 35                                               None   158176    2020-07-23
# 25  {0: 'Matt Walker is a brain scientist trying t...    57721    2020-07-15
# 33  {0: 'Matt Walker is a brain scientist trying t...    55141    2020-07-22
# 34  {0: '"Ethan Hawke has quietly emerged as perha...   553707    2020-06-25
# 31  {0: 'Kwame Owusu-Kesse ensures the programming...   515868    2020-06-18
# 32                                               None   183784    2020-07-21
#
#    published_date                  event native_lang  \
# 3      2020-06-26         TED@WellsFargo          en
# 5      2020-06-30      TEDxCapeTownWomen          en
# 10     2020-07-06                 TED-Ed          en
# 2      2020-06-26          TEDWomen 2019          en
# 23     2020-07-14               TED2020           en
# 17     2020-07-09               TED2020           en
# 6      2020-07-01            TEDMED 2020          en
# 4      2020-06-30               TED2020           en
# 12     2020-07-06                 TED-Ed          en
# 11     2020-07-06                 TED-Ed          en
# 1      2020-06-25               TED2020           en
# 14     2020-07-06                 TED-Ed          en
# 0      2020-06-25               TED2020           en
# 15     2020-07-07                 TED-Ed          en
# 18     2020-07-09                 TED-Ed          en
# 8      2020-07-01               TED2020           en
# 9      2020-07-02                TEDxCSU          en
# 7      2020-07-01               TED2020           en
# 21     2020-07-13            TEDMED 2020          en
# 13     2020-07-06               TED2020           en
# 16     2020-07-08               TED2020           en
# 27     2020-07-16                 TED-Ed          en
# 24     2020-07-14                 TED-Ed          en
# 22     2020-07-13      Build Back Better          en
# 19     2020-07-13               TED2020           en
# 26     2020-07-15           TEDxMileHigh          en
# 29     2020-07-20           TEDxMileHigh          en
# 28     2020-07-16               TED2020           en
# 20     2020-07-13                 TED-Ed          en
# 30     2020-07-21                 TED-Ed          en
# 35     2020-07-23                 TED-Ed          en
# 25     2020-07-15  Sleeping with Science          en
# 33     2020-07-22  Sleeping with Science          en
# 34     2020-07-23               TED2020           en
# 31     2020-07-21               TED2020           en
# 32     2020-07-21                 TED-Ed          en
#
#                                        available_lang comments duration  \
# 3              [ar, el, en, es, fr, pt-br, ro, zh-tw]       16      840
# 5              [en, es, fa, mr, pt, pt-br, tr, zh-cn]        6      880
# 10  [en, fa, fr, ja, my, pl, pt, pt-br, ro, tr, zh...        0      302
# 2               [ckb, en, es, hi, hr, ku, pt, ro, tr]       16      851
# 23                        [ar, en, es, nl, ro, zh-tw]        3      356
# 17                                               [en]       18     1514
# 6                     [ar, bg, en, fr, ko, ro, zh-tw]        8      953
# 4                      [en, hr, my, pt, pt-br, zh-cn]       11      674
# 12                     [en, hu, pt, pt-br, tr, zh-tw]        0      363
# 11              [en, fr, pt, pt-br, tr, zh-cn, zh-tw]        0      274
# 1                              [en, pt-br, tr, zh-cn]       26      791
# 14          [ar, en, my, pt, pt-br, tr, zh-cn, zh-tw]        0      290
# 0                                            [en, nl]       52     3405
# 15  [ar, ckb, en, es, fr, hi, hr, ku, pt, pt-br, z...        0      302
# 18                        [en, my, pt, ro, tr, zh-tw]        0      294
# 8                                  [en, pt-br, zh-tw]       22      815
# 9                                 [ar, en, fr, pt-br]       21      919
# 7                                        [en, nl, tr]      117     2587
# 21                            [en, fr, hr, pt, pt-br]       13      891
# 13                        [en, mr, ru, tr, uz, zh-tw]       23      429
# 16                         [el, en, pt-br, tr, zh-tw]        9      531
# 27     [ar, en, es, fr, ja, ku, ro, th, zh-cn, zh-tw]        0      236
# 24                     [en, hu, my, pt-br, tr, zh-tw]        0      264
# 22                                           [ar, en]        0     1592
# 19                                [en, es, fa, zh-tw]       36      658
# 26                            [el, en, fr, hi, zh-cn]        9      615
# 29                                    [el, en, pt-br]        8      867
# 28                                       [en, fr, hi]       12      628
# 20                 [en, es, fa, hi, tr, zh-cn, zh-tw]        0      310
# 30                                 [en, pt-br, zh-tw]        0      291
# 35                               [ckb, en, my, zh-tw]        0      261
# 25                                [en, fr, pt-br, tr]        7      287
# 33                                       [en, fr, hi]        5      294
# 34                                       [en, my, ro]       28      556
# 31                                           [en, tr]        8      396
# 32                                [en, es, fr, zh-tw]        0      269
#
#                                                topics  \
# 3   [humanity, community, communication, personal ...
# 5   [history, food, indigenous peoples, culture, a...
# 10  [education, TED-Ed, language, animation, speec...
# 2   [leadership, government, women, gender equalit...
# 23  [science, animals, exploration, Antarctica, na...
# 17  [nature, animals, humanity, climate change, co...
# 6   [cancer, illness, life, health care, mental he...
# 4   [life, adventure, personal growth, identity, s...
# 12  [TED-Ed, animation, education, indigenous peop...
# 11               [TED-Ed, education, math, animation]
# 1   [storytelling, media, arts, relationships, jou...
# 14  [math, education, history, TED-Ed, animation, ...
# 0   [environment, climate change, global issues, e...
# 15  [TED-Ed, animation, education, storytelling, c...
# 18  [TED-Ed, animation, government, education, his...
# 8   [art, history, race, painting, social change, ...
# 9   [gender, race, Gender spectrum, Transgender, s...
# 7   [coronavirus, pandemic, science, public health...
# 21  [violence, United States, crime, cities, inequ...
# 13  [Africa, journalism, humor, corruption, activi...
# 16  [technology, robots, innovation, business, ind...
# 27  [education, ancient world, TED-Ed, animation, ...
# 24  [TED-Ed, education, language, animation, ancie...
# 22          [education, society, future, Middle East]
# 19  [science, biology, nature, art, innovation, sc...
# 26  [activism, inequality, race, social change, TE...
# 29  [violence, guns, big problems, TEDx, activism,...
# 28  [democracy, leadership, community, social chan...
# 20  [TED-Ed, education, animation, natural disaste...
# 30  [TED-Ed, animation, education, history, war, r...
# 35  [education, TED-Ed, speech, animation, neurolo...
# 25               [sleep, health, human body, science]
# 33               [sleep, science, health, human body]
# 34  [creativity, arts, life, humanity, vulnerabili...
# 31  [coronavirus, education, community, Audacious ...
# 32  [TED-Ed, education, animation, history, war, v...
#
#                                         related_talks  \
# 3   {55061: 'The language of being human', 1533: '...
# 5   {24455: 'The history of chocolate', 424: 'The ...
# 10  {6857: 'The benefits of a bilingual brain', 24...
# 2   {59155: 'How women are revolutionizing Rwanda'...
# 23  {2511: 'Drawings that show the beauty and frag...
# 17  {340: 'How humans and animals can live togethe...
# 6   {55027: 'The beautiful balance between courage...
# 4   {60183: '2 questions to uncover your passion -...
# 12  {18514: 'Did the Amazons really exist?', 46519...
# 11  {17849: 'Can you solve the giant cat army ridd...
# 1   {2665: 'If a story moves you, act on it', 2813...
# 14  {23981: 'The most groundbreaking scientist you...
# 0   {2441: 'The case for optimism on climate chang...
# 15  {60411: 'The tale of the doctor who defied Dea...
# 18  {62865: 'What really happened during the Salem...
# 8   {2826: 'Can art amend history?', 64511: 'How r...
# 9   {36659: 'A short history of trans people's lon...
# 7   {61301: 'How we must respond to the coronaviru...
# 21  {46535: 'How we can make racism a solvable pro...
# 13  {59152: '3 ways to uproot a culture of corrupt...
# 16  {59153: 'A fascinating time capsule of human f...
# 27  {59150: 'The Egyptian myth of Isis and the sev...
# 24  {24485: 'The world's most mysterious book', 63...
# 22  {23658: ' How I'm using LEGO to teach Arabic',...
# 19  {52269: 'Why "biofabrication" is the next indu...
# 26  {2629: 'The urgency of intersectionality', 641...
# 29  {14608: 'A Parkland teacher's homework for us ...
# 28  {46575: 'How to use family dinner to teach pol...
# 20  {24060: 'How tsunamis work', 61316: 'Why isn't...
# 30  {48275: 'A day in the life of a Celtic Druid',...
# 35  {63654: 'What do all languages have in common?...
# 25  {41105: 'Sleep is your superpower', 61900: 'Wh...
# 33  {65060: 'A walk through the stages of sleep', ...
# 34  {64173: 'How drawing can set you free', 60752:...
# 31  {63813: 'How to quickly scale up contact traci...
# 32  {46592: 'The myth of Jason and the Argonauts '...
#
#                                                   url  \
# 3   https://www.ted.com/talks/matt_trombley_the_be...
# 5   https://www.ted.com/talks/aparna_pallavi_what_...
# 10  https://www.ted.com/talks/cameron_morin_what_d...
# 2   https://www.ted.com/talks/h_e_ellen_johnson_si...
# 23  https://www.ted.com/talks/ariel_waldman_the_in...
# 17  https://www.ted.com/talks/jane_goodall_every_d...
# 6   https://www.ted.com/talks/shekinah_elmore_the_...
# 4   https://www.ted.com/talks/tracy_edwards_stop_b...
# 12  https://www.ted.com/talks/dustin_tahmahkera_th...
# 11  https://www.ted.com/talks/dan_finkel_can_you_s...
# 1   https://www.ted.com/talks/jad_abumrad_how_doll...
# 14  https://www.ted.com/talks/pratik_aghor_the_gre...
# 0   https://www.ted.com/talks/al_gore_the_new_urge...
# 15  https://www.ted.com/talks/iseult_gillespie_the...
# 18  https://www.ted.com/talks/rod_phillips_what_ha...
# 8   https://www.ted.com/talks/titus_kaphar_can_bea...
# 9   https://www.ted.com/talks/d_l_stewart_scenes_f...
# 7   https://www.ted.com/talks/bill_gates_how_the_p...
# 21  https://www.ted.com/talks/thomas_abt_why_viole...
# 13  https://www.ted.com/talks/adeola_fayehun_afric...
# 16  https://www.ted.com/talks/ali_kashani_a_friend...
# 27  https://www.ted.com/talks/alex_gendler_the_egy...
# 24  https://www.ted.com/talks/susan_lupack_the_rac...
# 22  https://www.ted.com/talks/ahmad_m_hasnah_rethi...
# 19  https://www.ted.com/talks/christina_agapakis_w...
# 26  https://www.ted.com/talks/nita_mosby_tyler_wan...
# 29  https://www.ted.com/talks/tom_teves_a_call_to_...
# 28  https://www.ted.com/talks/shari_davis_what_if_...
# 20  https://www.ted.com/talks/steven_anderson_what...
# 30  https://www.ted.com/talks/philip_freeman_the_r...
# 35  https://www.ted.com/talks/gareth_gaskell_how_d...
# 25  https://www.ted.com/talks/matt_walker_a_walk_t...
# 33  https://www.ted.com/talks/matt_walker_how_caff...
# 34  https://www.ted.com/talks/ethan_hawke_give_you...
# 31  https://www.ted.com/talks/kwame_owusu_kesse_a_...
# 32  https://www.ted.com/talks/iseult_gillespie_the...
#
#                                           description  \
# 3   How can we disagree with one another, respectf...
# 5   Around the world, Indigenous food cultures van...
# 10  Language is endlessly variable. Each of us can...
# 2   "I was the first woman president of an African...
# 23  In this tour of the microscopic world, explore...
# 17  Legendary primatologist Jane Goodall says that...
# 6   When your future is uncertain, how do you keep...
# 4   "Life doesn't go from A to B -- it's messy," s...
# 12  Late one night in 1871, a group of riders desc...
# 11  Ragnarok: The fabled end of the world, when gi...
# 1   How do you end a story? Host of "Radiolab" Jad...
# 14  When Nicolas Bourbaki applied to the American ...
# 0   The coronavirus brought much of the world to a...
# 15  In a small town, a proud mother showed off her...
# 18  On January 17, 1920, less than one hour after ...
# 8   An artwork's color or composition can pull you...
# 9   At the crossroads of life and livelihood, scho...
# 7   Bill Gates talks best (and worst) case scenari...
# 21  Reducing violence in cities in the US isn't th...
# 13  "Africa is like a sleeping giant," says journa...
# 16  Meet the friendly robot that could deliver you...
# 27  Long jealous of his older brother Osiris, the ...
# 24  In the early 1900s, archaeologist Sir Arthur E...
# 22  The pandemic has deepened the need to rethink ...
# 19  "We've been promised a future of chrome -- but...
# 26  A more equal world starts with you. Citing a f...
# 29  On July 20, 2012, a mass shooting in a movie t...
# 28  What if you could help decide how the governme...
# 20  In February of 1942, Mexican farmer Dionisio P...
# 30  One summer evening in 335 BCE, Alexander the G...
# 35  The average 20-year-old knows between 27,000 a...
# 25  Did you know you go on a journey every night a...
# 33  Caffeine wakes you up, and alcohol makes you n...
# 34  Reflecting on moments that shaped his life, ac...
# 31  Crisis interventions often focus on a single a...
# 32  In Colchis, the hide of a mystical flying ram ...
#
#                                            transcript
# 3   So our story started several years ago, when m...
# 5   Last year, I was living with this indigenous f...
# 10  Language is endlessly variable. Each of us can...
# 2   I was the first woman president of an African ...
# 23  Can you guess what this is? What if I told you...
# 17  Chris Anderson: Dr. Jane Goodall, welcome. Jan...
# 6   What's the worst that could happen? Almost exa...
# 4   Being able to navigate is an extraordinary gif...
# 12  Late one night in 1871, a group of riders desc...
# 11  Ragnarok. The fabled end of the world, when gi...
# 1   I want to tell you about my search for purpose...
# 14  When Nicolas Bourbaki applied to the American ...
# 0   Chris Anderson: Al, welcome. So look, just six...
# 15  In the sun-dappled streets of a small town, a ...
# 18  On January 17, 1920, six armed men robbed a Ch...
# 8   I believe there is beauty in hearing the voice...
# 9   Hello. Hey. (Laughter) As you just heard, my n...
# 7   Chris Anderson: Welcome, Bill Gates. Bill Gate...
# 21  You are a trauma surgeon, working in the midni...
# 13  What's up, people? First of all, I cannot beli...
# 16  Food delivery. It's the thing that saves mille...
# 27  It was a feast like Egypt had never seen befor...
# 24  In the early 1900s on the island of Crete, Bri...
# 22  Hello, I am going to be joined shortly by Dr. ...
# 19  A briefcase full of poop changed my life. Ten ...
# 26  You can ask anyone you want, and they will tel...
# 29  Every parent's worst nightmare: July 20, 2012,...
# 28  My name is Shari Davis, and let's be honest, I...
# 20  In February of 1942, Mexican farmer Dionisio P...
# 30  One summer evening in 335 BCE, Alexander the G...
# 35  The average 20 year old knows between 27,000 a...
# 25  Sleep is perhaps the single most effective thi...
# 33  Many of us like to start the day with a cup of...
# 34  I was hoping today to talk a little bit about ...
# 31  Good evening. It is such a blessing to work at...
# 32  In the center of Colchis in an enchanted garde...

# %%
driver=webdriver.Chrome()

# %%
driver.set_window_size(1024,1024)

# %%
url=df2['url'][0]
driver.get(str(url))

# %%
# //*[@id="content"]/div/div[2]/div[1]/div[2]/div/div/div[2]/ul/li[4]/button/div/span/svg

# %%
driver.find_element_by_xpath('//button[@class="sb"]').click()

# %%
types = driver.find_elements_by_xpath('//ul/span/div/div/button')
types[1].click()

# %%
driver.find_element_by_xpath("//a[contains(.//text(),' audio')]").click() 
# audio dowload, video download시 video로 변경

# %%
df[df['talk_id']==1]['url'][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-f9bb4194f690> in <module>
# ----> 1 df[df['talk_id']==1]['url'][0]
#
# NameError: name 'df' is not defined

# %%
driver.close()
